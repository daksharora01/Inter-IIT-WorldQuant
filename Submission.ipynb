# %%
# !pip install requests

import requests
from urllib.parse import urljoin
s = requests.Session()
# Save credentials into session
s.auth = ("username", "Password")

# Send a POST request to the /authentication API
response = s.post('https://api.worldquantbrain.com/authentication')
if response.status_code == requests.status_codes.codes.unauthorized:
    if response.headers["WWW-Authenticate"] == "persona":
        # Outputs the URL to access through the browser to complete biometrics authentication
        input("Complete biometrics authentication and press any key to continue: " + urljoin(response.url, response.headers["Location"]))
        response = s.post(urljoin(response.url, response.headers["Location"]))
    else:
        print("incorrect email and password")
# Out:
# Requirement already satisfied: requests in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from requests) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from requests) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from requests) (2.0.4)
# Complete biometrics authentication and press any key to continue: https://api.worldquantbrain.com/authentication/persona?inquiry=inq_MnnatERHbVuvixeLk7f6jpvdj

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pip>=21.3.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (22.3.1)
# Requirement already satisfied: notebook>=5.5.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (6.5.2)
# Requirement already satisfied: pandas>=0.23.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: requests>=2.18.4 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (2.31.0)
# Requirement already satisfied: seaborn>=0.8.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (0.12.2)
# Requirement already satisfied: matplotlib>=2.2.2 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (3.7.0)
# Requirement already satisfied: tqdm>=4.64.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (4.64.1)
# Requirement already satisfied: plotly>=5.13.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (5.18.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (5.2.0)
# Requirement already satisfied: jinja2 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: nbformat in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (5.7.0)
# Requirement already satisfied: nbconvert>=5 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (6.5.4)
# Requirement already satisfied: jupyter-client>=5.3.4 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (7.3.4)
# Requirement already satisfied: terminado>=0.8.3 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (0.17.1)
# Requirement already satisfied: ipykernel in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (6.19.2)
# Requirement already satisfied: prometheus-client in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (0.14.1)
# Requirement already satisfied: ipython-genutils in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (0.5.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (1.5.6)
# Requirement already satisfied: traitlets>=4.2.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (5.7.1)
# Requirement already satisfied: tornado>=6.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (6.1)
# Requirement already satisfied: argon2-cffi in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (21.3.0)
# Requirement already satisfied: pyzmq>=17 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from notebook>=5.5.0->-r requirements.txt (line 2)) (23.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from pandas>=0.23.0->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from pandas>=0.23.0->-r requirements.txt (line 3)) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from pandas>=0.23.0->-r requirements.txt (line 3)) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from requests>=2.18.4->-r requirements.txt (line 4)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from requests>=2.18.4->-r requirements.txt (line 4)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from requests>=2.18.4->-r requirements.txt (line 4)) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from requests>=2.18.4->-r requirements.txt (line 4)) (1.26.14)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (1.0.5)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.2.2->-r requirements.txt (line 6)) (4.25.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from plotly>=5.13.0->-r requirements.txt (line 8)) (8.0.1)
# Requirement already satisfied: entrypoints in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from jupyter-client>=5.3.4->notebook>=5.5.0->-r requirements.txt (line 2)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from jupyter-core>=4.6.1->notebook>=5.5.0->-r requirements.txt (line 2)) (2.5.2)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=5.5.0->-r requirements.txt (line 2)) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=5.5.0->-r requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: tinycss2 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=5.5.0->-r requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: bleach in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=5.5.0->-r requirements.txt (line 2)) (4.1.0)
# Requirement already satisfied: beautifulsoup4 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=5.5.0->-r requirements.txt (line 2)) (4.11.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=5.5.0->-r requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: pygments>=2.4.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=5.5.0->-r requirements.txt (line 2)) (2.11.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=5.5.0->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: lxml in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=5.5.0->-r requirements.txt (line 2)) (4.9.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=5.5.0->-r requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=5.5.0->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: defusedxml in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=5.5.0->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbconvert>=5->notebook>=5.5.0->-r requirements.txt (line 2)) (0.5.13)
# Requirement already satisfied: jsonschema>=2.6 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbformat->notebook>=5.5.0->-r requirements.txt (line 2)) (4.17.3)
# Requirement already satisfied: fastjsonschema in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from nbformat->notebook>=5.5.0->-r requirements.txt (line 2)) (2.16.2)
# Requirement already satisfied: six>=1.5 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=0.23.0->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: ptyprocess in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from terminado>=0.8.3->notebook>=5.5.0->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from argon2-cffi->notebook>=5.5.0->-r requirements.txt (line 2)) (21.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (8.10.0)
# Requirement already satisfied: debugpy>=1.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (1.5.1)
# Requirement already satisfied: psutil in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (5.9.0)
# Requirement already satisfied: appnope in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (3.0.36)
# Requirement already satisfied: pickleshare in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (0.18.1)
# Requirement already satisfied: decorator in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (5.1.1)
# Requirement already satisfied: stack-data in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: backcall in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.5.0->-r requirements.txt (line 2)) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=5.5.0->-r requirements.txt (line 2)) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.5.0->-r requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: websocket-client in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.5.0->-r requirements.txt (line 2)) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.5.0->-r requirements.txt (line 2)) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=5.5.0->-r requirements.txt (line 2)) (2.3.2.post1)
# Requirement already satisfied: webencodings in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=5.5.0->-r requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.5.0->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: pycparser in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.5.0->-r requirements.txt (line 2)) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (0.8.3)
# Requirement already satisfied: wcwidth in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (0.2.5)
# Requirement already satisfied: asttokens in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: executing in /Users/ayushdadhich/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=5.5.0->-r requirements.txt (line 2)) (0.8.3)

# %%
import brain_lib as brain
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px

# %%
s = brain.start_session()
# Out:
# Complete biometrics authentication and press any key to continue:
# https://api.worldquantbrain.com/authentication/persona?inquiry=inq_Zt4ckDUSzasz5u8vcx75xNfF
#
# h

# %% [markdown]
# ### In line with our hypothesis indicating the significant influence of implied volatility on option pricing, we selected 'option8' .

# %%
dataset_id = 'option8'
dataset_id
# Out:
# 'option8'

# %%
# Loading all datafields in 'option8' data set
datafields_df = hf.get_datafields(s, dataset_id=dataset_id)
datafields_df
# Out:
#                            id  \
# 0    historical_volatility_10
# 1   historical_volatility_120
# 2   historical_volatility_150
# 3   historical_volatility_180
# 4    historical_volatility_20
# ..                        ...
# 59   parkinson_volatility_180
# 60    parkinson_volatility_20
# 61    parkinson_volatility_30
# 62    parkinson_volatility_60
# 63    parkinson_volatility_90
#
#                                           description  \
# 0   Close-to-close Historical volatility over 10 days
# 1   Close-to-close Historical volatility over 120 ...
# 2   Close-to-close Historical volatility over 150 ...
# 3   Close-to-close Historical volatility over 180 ...
# 4   Close-to-close Historical volatility over 20 days
# ..                                                ...
# 59  Parkinson models' Historical volatility over 1...
# 60  Parkinson models' Historical volatility over 2...
# 61  Parkinson models' Historical volatility over 3...
# 62  Parkinson models' Historical volatility over 6...
# 63  Parkinson models' Historical volatility over 9...
#
#                                          dataset category  \
# 0   {'id': 'option8', 'name': 'Volatility Data'}   option
# 1   {'id': 'option8', 'name': 'Volatility Data'}   option
# 2   {'id': 'option8', 'name': 'Volatility Data'}   option
# 3   {'id': 'option8', 'name': 'Volatility Data'}   option
# 4   {'id': 'option8', 'name': 'Volatility Data'}   option
# ..                                           ...      ...
# 59  {'id': 'option8', 'name': 'Volatility Data'}   option
# 60  {'id': 'option8', 'name': 'Volatility Data'}   option
# 61  {'id': 'option8', 'name': 'Volatility Data'}   option
# 62  {'id': 'option8', 'name': 'Volatility Data'}   option
# 63  {'id': 'option8', 'name': 'Volatility Data'}   option
#
#                  subcategory region  delay universe    type  coverage  \
# 0   option-option-volatility    USA      1  TOP3000  MATRIX    0.6983
# 1   option-option-volatility    USA      1  TOP3000  MATRIX    0.7004
# 2   option-option-volatility    USA      1  TOP3000  MATRIX    0.7014
# 3   option-option-volatility    USA      1  TOP3000  MATRIX    0.7023
# 4   option-option-volatility    USA      1  TOP3000  MATRIX    0.6983
# ..                       ...    ...    ...      ...     ...       ...
# 59  option-option-volatility    USA      1  TOP3000  MATRIX    0.7022
# 60  option-option-volatility    USA      1  TOP3000  MATRIX    0.6983
# 61  option-option-volatility    USA      1  TOP3000  MATRIX    0.6981
# 62  option-option-volatility    USA      1  TOP3000  MATRIX    0.6984
# 63  option-option-volatility    USA      1  TOP3000  MATRIX    0.6994
#
#    turnover  userCount  alphaCount
# 0      None        235         565
# 1      None        177         670
# 2      None        105         319
# 3      None        202       14401
# 4      None        142         481
# ..      ...        ...         ...
# 59     None        145         459
# 60     None         85         250
# 61     None         76         177
# 62     None         82         398
# 63     None        122         463
#
# [64 rows x 13 columns]

# %%
# Simulating all datafields of the whole dataset 
expression_list =[f'{x}' for x  in datafields_df.id.values.tolist()]

# %%
alpha_list = [brain.generate_alpha(x, region= "USA",truncation = 0.08, universe = "TOP3000",pasteurization = 'ON', decay = 4 ,neutralization = "SUBINDUSTRY") for x in expression_list]

# %%
result = brain.simulate_alpha_list_multi(s, alpha_list)
# Out:
# 100%|███████████████████████████████████████████| 22/22 [07:04<00:00, 19.29s/it]

# %%
result_st1 = hf.prettify_result(result, detailed_tests_view=False)
result_st1
# Out:
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   6633489   20000000        1059         1410    0.1442   0.0674    0.4422
# 1   6537068   20000000        1060         1409    0.1479   0.0665    0.4457
# 2   6831678   20000000        1037         1414    0.1440   0.0695    0.5276
# 3   6532091   20000000        1039         1411    0.1311   0.0664    0.5155
# 4   6518638   20000000        1058         1412    0.1441   0.0663    0.4429
# ..      ...        ...         ...          ...       ...      ...       ...
# 59   282901   20000000        1198         1106    0.5592   0.0029    0.2324
# 60  -660893   20000000        1188         1116    0.5793  -0.0067    0.3095
# 61  -534988   20000000        1196         1108    0.5672  -0.0054    0.2440
# 62 -1972513   20000000        1158         1146    0.5873  -0.0201    0.3872
# 63 -2222173   20000000        1146         1158    0.5911  -0.0226    0.4377
#
#       margin  fitness  sharpe alpha_id                        expression  \
# 0   0.000936     0.34    0.50  Zja8nY0       implied_volatility_call_180
# 1   0.000899     0.34    0.50  Mb6EQPn       implied_volatility_call_270
# 2   0.000965     0.33    0.47  onablNm        implied_volatility_mean_60
# 3   0.001013     0.33    0.46  v5AElrz        implied_volatility_mean_90
# 4   0.000920     0.33    0.49  l7anOe7       implied_volatility_call_150
# ..       ...      ...     ...      ...                               ...
# 59  0.000010     0.00    0.05  YNaV0aA  implied_volatility_mean_skew_120
# 60 -0.000023    -0.01   -0.13  VXNrPbw   implied_volatility_mean_skew_60
# 61 -0.000019    -0.01   -0.11  WNlZG5O   implied_volatility_mean_skew_90
# 62 -0.000068    -0.05   -0.25  5LJmOKM   implied_volatility_mean_skew_20
# 63 -0.000076    -0.05   -0.24  RNeO8bd   implied_volatility_mean_skew_10
#
#    concentrated_weight high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0                 FAIL          PASS             FAIL        FAIL       FAIL
# 1                 FAIL          PASS             FAIL        FAIL       FAIL
# 2                 FAIL          PASS             FAIL        FAIL       FAIL
# 3                 FAIL          PASS             FAIL        FAIL       FAIL
# 4                 FAIL          PASS             FAIL        FAIL       FAIL
# ..                 ...           ...              ...         ...        ...
# 59                PASS          PASS             FAIL        FAIL       FAIL
# 60                PASS          PASS             FAIL        FAIL       FAIL
# 61                PASS          PASS             FAIL        FAIL       FAIL
# 62                PASS          PASS             FAIL        FAIL       FAIL
# 63                PASS          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover matches_themes
# 0                     PASS         PASS        WARNING
# 1                     PASS         PASS        WARNING
# 2                     PASS         PASS        WARNING
# 3                     PASS         PASS        WARNING
# 4                     PASS         PASS        WARNING
# ..                     ...          ...            ...
# 59                    FAIL         PASS        WARNING
# 60                    FAIL         PASS        WARNING
# 61                    FAIL         PASS        WARNING
# 62                    PASS         PASS        WARNING
# 63                    PASS         PASS        WARNING
#
# [64 rows x 20 columns]

# %% [markdown]
# ### Selecting top 5 performing datafields in the given dataset on the basis of performance.

# %%
a = result_st1['expression'].tolist()
top_5  = a[:5]

# %%
# Using different operators on the selected datafields to find the best performing combination.
opt_list = ['ts_rank(' , 'ts_quantile(' , 'ts_zscore(' , 'ts_mean(', 'ts_delay(','ts_median(' , 'ts_av_diff(' , 'ts_std_dev(']

# %%
avg_sharpe0 = []
for y in opt_list:
    exp_list = [f'{y}  {x}  ,360)' for x  in top_5]
    alph_list = [brain.generate_alpha(x, region= "USA",truncation = 0.08, universe = "TOP3000",pasteurization = 'ON', decay = 4 ,neutralization = "SUBINDUSTRY") for x in exp_list]
    result = brain.simulate_alpha_list_multi(s, alph_list)
    result_st = hf.prettify_result(result, detailed_tests_view=False)
    avg_sharpe = result_st['sharpe'].mean()
    avg_sharpe0.append(avg_sharpe)
    print(f'Average Sharpe for {y}) is: {avg_sharpe}')
    display(result_st)
# Out:
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 5/5 [01:12<00:00, 14.42s/it]
# Average Sharpe for ts_rank() is: 1.1380000000000001
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  5198578   20000000        1238         1231    0.2526   0.0529    0.0579
# 1  5237430   20000000        1240         1230    0.2527   0.0532    0.0595
# 2  5146570   20000000        1236         1234    0.2563   0.0523    0.0571
# 3  4283314   20000000        1238         1213    0.2449   0.0435    0.0743
# 4  3997443   20000000        1237         1213    0.2282   0.0406    0.0701
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000419     0.57    1.24  EqQjVYL
# 1  0.000421     0.57    1.25  OnWLYXY
# 2  0.000408     0.56    1.24  gmalWKO
# 3  0.000356     0.43    1.01  Mb6E6Nr
# 4  0.000356     0.40    0.95  WNlZYEN
#
#                                      expression concentrated_weight  \
# 0  ts_rank(  implied_volatility_call_180  ,360)                PASS
# 1  ts_rank(  implied_volatility_call_150  ,360)                PASS
# 2  ts_rank(  implied_volatility_call_270  ,360)                PASS
# 3   ts_rank(  implied_volatility_mean_60  ,360)                PASS
# 4   ts_rank(  implied_volatility_mean_90  ,360)                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
# 1          PASS             FAIL        FAIL       FAIL
# 2          PASS             FAIL        FAIL       FAIL
# 3          PASS             FAIL        FAIL       FAIL
# 4          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING
# 1                    PASS         PASS        WARNING
# 2                    PASS         PASS        WARNING
# 3                    FAIL         PASS        WARNING
# 4                    FAIL         PASS        WARNING
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 5/5 [01:16<00:00, 15.33s/it]
# Average Sharpe for ts_quantile() is: 1.108
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  5402756   20000000        1250         1217    0.2649   0.0549    0.0694
# 1  5298557   20000000        1246         1222    0.2691   0.0539    0.0671
# 2  5368725   20000000        1249         1219    0.2652   0.0546    0.0675
# 3  4226808   20000000        1245         1204    0.2568   0.0430    0.0843
# 4  4137347   20000000        1248         1201    0.2409   0.0421    0.0804
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000415     0.56    1.22  Jn89E1W
# 1  0.000400     0.55    1.22  enajwQM
# 2  0.000412     0.55    1.22  Kng1drz
# 3  0.000335     0.39    0.95  6RMkVKJ
# 4  0.000349     0.39    0.93  gma2OL0
#
#                                          expression concentrated_weight  \
# 0  ts_quantile(  implied_volatility_call_150  ,360)                PASS
# 1  ts_quantile(  implied_volatility_call_270  ,360)                PASS
# 2  ts_quantile(  implied_volatility_call_180  ,360)                PASS
# 3   ts_quantile(  implied_volatility_mean_60  ,360)                PASS
# 4   ts_quantile(  implied_volatility_mean_90  ,360)                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
# 1          PASS             FAIL        FAIL       FAIL
# 2          PASS             FAIL        FAIL       FAIL
# 3          PASS             FAIL        FAIL       FAIL
# 4          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING
# 1                    PASS         PASS        WARNING
# 2                    PASS         PASS        WARNING
# 3                    FAIL         PASS        WARNING
# 4                    PASS         PASS        WARNING
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 5/5 [01:08<00:00, 13.61s/it]
# Average Sharpe for ts_zscore() is: 1.0020000000000002
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  5375863   20000000        1169         1300    0.2532   0.0547    0.0864
# 1  5424375   20000000        1167         1301    0.2534   0.0551    0.0879
# 2  5224738   20000000        1170         1299    0.2573   0.0531    0.0838
# 3  4299297   20000000        1151         1298    0.2316   0.0437    0.0998
# 4  4296915   20000000        1145         1305    0.2505   0.0437    0.1073
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000432     0.52    1.12  bNaw5k6
# 1  0.000435     0.52    1.11  Mb6ro8L
# 2  0.000413     0.50    1.11  v5AQ3Mb
# 3  0.000377     0.36    0.84  w5orMzQ
# 4  0.000349     0.35    0.83  6RMkv8P
#
#                                        expression concentrated_weight  \
# 0  ts_zscore(  implied_volatility_call_180  ,360)                PASS
# 1  ts_zscore(  implied_volatility_call_150  ,360)                PASS
# 2  ts_zscore(  implied_volatility_call_270  ,360)                PASS
# 3   ts_zscore(  implied_volatility_mean_90  ,360)                PASS
# 4   ts_zscore(  implied_volatility_mean_60  ,360)                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
# 1          PASS             FAIL        FAIL       FAIL
# 2          PASS             FAIL        FAIL       FAIL
# 3          PASS             FAIL        FAIL       FAIL
# 4          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING
# 1                    PASS         PASS        WARNING
# 2                    PASS         PASS        WARNING
# 3                    PASS         PASS        WARNING
# 4                    PASS         PASS        WARNING
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 5/5 [01:01<00:00, 12.37s/it]
# Average Sharpe for ts_mean() is: -0.05200000000000001
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  7570363   20000000        1108         1582    0.0164   0.0770    0.5655
# 1  6097356   20000000        1111         1579    0.0161   0.0620    0.5647
# 2 -4345642   20000000        1123         1569    0.0141  -0.0442    0.5384
# 3 -4252702   20000000        1124         1568    0.0141  -0.0432    0.5290
# 4 -4377761   20000000        1122         1570    0.0141  -0.0445    0.5417
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.009401     0.29    0.37  ZjaJeEx
# 1  0.007712     0.22    0.31  onadQXb
# 2 -0.006286    -0.18   -0.31  l7ambjn
# 3 -0.006135    -0.18   -0.31  1oWMQp6
# 4 -0.006325    -0.19   -0.32  OnW3Kz7
#
#                                      expression concentrated_weight  \
# 0   ts_mean(  implied_volatility_mean_60  ,360)                FAIL
# 1   ts_mean(  implied_volatility_mean_90  ,360)                FAIL
# 2  ts_mean(  implied_volatility_call_180  ,360)                FAIL
# 3  ts_mean(  implied_volatility_call_270  ,360)                FAIL
# 4  ts_mean(  implied_volatility_call_150  ,360)                FAIL
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
# 1          PASS             FAIL        FAIL       FAIL
# 2          PASS             FAIL        FAIL       FAIL
# 3          PASS             FAIL        FAIL       FAIL
# 4          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING
# 1                    PASS         PASS        WARNING
# 2                    PASS         PASS        WARNING
# 3                    PASS         PASS        WARNING
# 4                    PASS         PASS        WARNING
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 5/5 [01:04<00:00, 12.85s/it]
# Average Sharpe for ts_delay() is: 0.094
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  2015721   20000000         932         1251    0.1590   0.0205    0.6017
# 1  1945162   20000000         931         1252    0.1568   0.0198    0.6036
# 2  1932096   20000000         930         1253    0.1571   0.0196    0.6056
# 3  1062596   20000000         916         1257    0.1570   0.0108    0.6156
# 4  1269663   20000000         918         1255    0.1480   0.0129    0.6156
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000258     0.04    0.12  YNaewKo
# 1  0.000252     0.04    0.11  pnaLJrq
# 2  0.000250     0.04    0.11  Qn08r2p
# 3  0.000138     0.02    0.06  rb7x6gj
# 4  0.000174     0.02    0.07  enaj8dJ
#
#                                       expression concentrated_weight  \
# 0  ts_delay(  implied_volatility_call_270  ,360)                FAIL
# 1  ts_delay(  implied_volatility_call_180  ,360)                FAIL
# 2  ts_delay(  implied_volatility_call_150  ,360)                FAIL
# 3   ts_delay(  implied_volatility_mean_60  ,360)                FAIL
# 4   ts_delay(  implied_volatility_mean_90  ,360)                FAIL
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
# 1          PASS             FAIL        FAIL       FAIL
# 2          PASS             FAIL        FAIL       FAIL
# 3          PASS             FAIL        FAIL       FAIL
# 4          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING
# 1                    PASS         PASS        WARNING
# 2                    PASS         PASS        WARNING
# 3                    PASS         PASS        WARNING
# 4                    PASS         PASS        WARNING
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 5/5 [01:12<00:00, 14.58s/it]
# Average Sharpe for ts_median() is: 0.252
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  5388954   20000000        1138         1554    0.0174   0.0548    0.5106
# 1  5535471   20000000        1137         1554    0.0174   0.0563    0.5048
# 2  5301652   20000000        1136         1555    0.0175   0.0539    0.5144
# 3  3839651   20000000        1123         1567    0.0178   0.0390    0.5622
# 4  3762569   20000000        1124         1566    0.0176   0.0383    0.5672
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.006294     0.19    0.29  Xka0wJa
# 1  0.006462     0.19    0.29  Jn890Qx
# 2  0.006176     0.18    0.28  OnW3wjq
# 3  0.004385     0.11    0.20  enaj8Qz
# 4  0.004342     0.11    0.20  99lnP3K
#
#                                        expression concentrated_weight  \
# 0  ts_median(  implied_volatility_call_180  ,360)                FAIL
# 1  ts_median(  implied_volatility_call_270  ,360)                FAIL
# 2  ts_median(  implied_volatility_call_150  ,360)                FAIL
# 3   ts_median(  implied_volatility_mean_60  ,360)                FAIL
# 4   ts_median(  implied_volatility_mean_90  ,360)                FAIL
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
# 1          PASS             FAIL        FAIL       FAIL
# 2          PASS             FAIL        FAIL       FAIL
# 3          PASS             FAIL        FAIL       FAIL
# 4          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING
# 1                    PASS         PASS        WARNING
# 2                    PASS         PASS        WARNING
# 3                    PASS         PASS        WARNING
# 4                    PASS         PASS        WARNING
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 5/5 [01:05<00:00, 13.04s/it]
# Average Sharpe for ts_av_diff() is: 0.462
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  6178048   20000000        1207         1243    0.2076   0.0628    0.2359
# 1  7317486   20000000        1218         1252    0.3979   0.0744    0.2738
# 2  6964788   20000000        1218         1252    0.4038   0.0708    0.2752
# 3  6904200   20000000        1216         1254    0.3975   0.0702    0.2705
# 4  4242905   20000000        1205         1246    0.2159   0.0431    0.3866
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000605     0.25    0.45  7xYp0av
# 1  0.000374     0.24    0.55  qn7RvrP
# 2  0.000351     0.22    0.53  pnaLorg
# 3  0.000353     0.22    0.53  knaAb1P
# 4  0.000400     0.11    0.25  GnmRYA0
#
#                                         expression concentrated_weight  \
# 0   ts_av_diff(  implied_volatility_mean_90  ,360)                FAIL
# 1  ts_av_diff(  implied_volatility_call_180  ,360)                FAIL
# 2  ts_av_diff(  implied_volatility_call_270  ,360)                FAIL
# 3  ts_av_diff(  implied_volatility_call_150  ,360)                FAIL
# 4   ts_av_diff(  implied_volatility_mean_60  ,360)                FAIL
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
# 1          PASS             FAIL        FAIL       FAIL
# 2          PASS             FAIL        FAIL       FAIL
# 3          PASS             FAIL        FAIL       FAIL
# 4          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING
# 1                    PASS         PASS        WARNING
# 2                    PASS         PASS        WARNING
# 3                    PASS         PASS        WARNING
# 4                    PASS         PASS        WARNING
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 5/5 [05:53<00:00, 70.63s/it]
# Average Sharpe for ts_std_dev() is: 0.03800000000000001
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  6673851   20000000         954         1729    0.0145   0.0679    0.7362
# 1  4933363   20000000         948         1735    0.0147   0.0502    0.5932
# 2 -1473459   20000000         939         1747    0.0144  -0.0150    0.3446
# 3 -1584395   20000000         936         1750    0.0145  -0.0161    0.3446
# 4 -1521956   20000000         937         1749    0.0144  -0.0155    0.3446
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.009339     0.21    0.29  RNegY3z
# 1  0.006839     0.18    0.28  onadzmk
# 2 -0.002081    -0.04   -0.12  YNaekrl
# 3 -0.002225    -0.05   -0.13  7xYpQb2
# 4 -0.002143    -0.05   -0.13  bNawMZr
#
#                                         expression concentrated_weight  \
# 0   ts_std_dev(  implied_volatility_mean_60  ,360)                FAIL
# 1   ts_std_dev(  implied_volatility_mean_90  ,360)                FAIL
# 2  ts_std_dev(  implied_volatility_call_150  ,360)                FAIL
# 3  ts_std_dev(  implied_volatility_call_270  ,360)                FAIL
# 4  ts_std_dev(  implied_volatility_call_180  ,360)                FAIL
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
# 1          PASS             FAIL        FAIL       FAIL
# 2          PASS             FAIL        FAIL       FAIL
# 3          PASS             FAIL        FAIL       FAIL
# 4          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    FAIL         PASS        WARNING
# 1                    FAIL         PASS        WARNING
# 2                    PASS         PASS        WARNING
# 3                    PASS         PASS        WARNING
# 4                    PASS         PASS        WARNING

# %%
for opt in range(len(opt_list)):
    print(f'Average Sharpe for {opt_list[opt]} is: {avg_sharpe0[opt]:.2f}')
# Out:
# Average Sharpe for ts_rank( is: 1.14
# Average Sharpe for ts_quantile( is: 1.11
# Average Sharpe for ts_zscore( is: 1.00
# Average Sharpe for ts_mean( is: -0.05
# Average Sharpe for ts_delay( is: 0.09
# Average Sharpe for ts_median( is: 0.25
# Average Sharpe for ts_av_diff( is: 0.46
# Average Sharpe for ts_std_dev( is: 0.04

# %% [markdown]
# ### The combination of the operator and field that demonstrates the highest efficacy is "ts_rank."

# %%
expression_list2 =[f'ts_rank({x},360)' for x  in top_5]

# %%
alpha_list2 = [brain.generate_alpha(x, region= "USA",truncation = 0.08, universe = "TOP3000",pasteurization = 'ON', decay = 4 ,neutralization = "SUBINDUSTRY") for x in expression_list2]

# %%
result2 = brain.simulate_alpha_list_multi(s, alpha_list2)
# Out:
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 5/5 [01:07<00:00, 13.57s/it]

# %%
result_st2 = hf.prettify_result(result2, detailed_tests_view=False)
result_st2
# Out:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  5198578   20000000        1238         1231    0.2526   0.0529    0.0579
# 1  5237430   20000000        1240         1230    0.2527   0.0532    0.0595
# 2  5146570   20000000        1236         1234    0.2563   0.0523    0.0571
# 3  4283314   20000000        1238         1213    0.2449   0.0435    0.0743
# 4  3997443   20000000        1237         1213    0.2282   0.0406    0.0701
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000419     0.57    1.24  EqQjVYL
# 1  0.000421     0.57    1.25  OnWLYXY
# 2  0.000408     0.56    1.24  gmalWKO
# 3  0.000356     0.43    1.01  Mb6E6Nr
# 4  0.000356     0.40    0.95  WNlZYEN
#
#                                  expression concentrated_weight high_turnover  \
# 0  ts_rank(implied_volatility_call_180,360)                PASS          PASS
# 1  ts_rank(implied_volatility_call_150,360)                PASS          PASS
# 2  ts_rank(implied_volatility_call_270,360)                PASS          PASS
# 3   ts_rank(implied_volatility_mean_60,360)                PASS          PASS
# 4   ts_rank(implied_volatility_mean_90,360)                PASS          PASS
#
#   is_ladder_sharpe low_fitness low_sharpe low_sub_universe_sharpe  \
# 0             FAIL        FAIL       FAIL                    PASS
# 1             FAIL        FAIL       FAIL                    PASS
# 2             FAIL        FAIL       FAIL                    PASS
# 3             FAIL        FAIL       FAIL                    FAIL
# 4             FAIL        FAIL       FAIL                    FAIL
#
#   low_turnover matches_themes
# 0         PASS        WARNING
# 1         PASS        WARNING
# 2         PASS        WARNING
# 3         PASS        WARNING
# 4         PASS        WARNING

# %% [markdown]
# ### Utilizing the zscore() operator post-normalization via ts_rank() facilitates data set rescaling to its original scale, ensuring standardization while preserving the initial data distribution.

# %%
expression_list3 =[f' zscore(ts_rank({x}, 360)) ' for x  in top_5]

# %%
alpha_list3 = [brain.generate_alpha(x, region= "USA",truncation = 0.08, universe = "TOP3000",pasteurization = 'ON', decay = 4 ,neutralization = "SUBINDUSTRY") for x in expression_list3]

# %%
result3 = brain.simulate_alpha_list_multi(s, alpha_list3)
# Out:
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 5/5 [01:33<00:00, 18.67s/it]

# %%
result_st3 = hf.prettify_result(result3, detailed_tests_view=False)
result_st3
# Out:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  5249593   20000000        1238         1231    0.2523   0.0534    0.0578
# 1  5294127   20000000        1240         1229    0.2523   0.0538    0.0593
# 2  5197910   20000000        1236         1233    0.2560   0.0528    0.0567
# 3  4290291   20000000        1238         1213    0.2449   0.0436    0.0738
# 4  4014847   20000000        1238         1213    0.2281   0.0408    0.0697
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000423     0.58    1.25  jnapq2W
# 1  0.000427     0.58    1.26  EqQj7M9
# 2  0.000413     0.57    1.25  2v5g38Z
# 3  0.000356     0.43    1.01  pna29Yg
# 4  0.000358     0.40    0.95  Gnm2ZVP
#
#                                           expression concentrated_weight  \
# 0   zscore(ts_rank(implied_volatility_call_180, 3...                PASS
# 1   zscore(ts_rank(implied_volatility_call_150, 3...                PASS
# 2   zscore(ts_rank(implied_volatility_call_270, 3...                PASS
# 3   zscore(ts_rank(implied_volatility_mean_60, 36...                PASS
# 4   zscore(ts_rank(implied_volatility_mean_90, 36...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
# 1          PASS             FAIL        FAIL       FAIL
# 2          PASS             FAIL        FAIL       FAIL
# 3          PASS             FAIL        FAIL       FAIL
# 4          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING
# 1                    PASS         PASS        WARNING
# 2                    PASS         PASS        WARNING
# 3                    FAIL         PASS        WARNING
# 4                    FAIL         PASS        WARNING

# %% [markdown]
# ## Opting for the top 3 expressions due to their better performance.

# %%
result_st3 = result_st3[0:3]
result_st3
# Out:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  5249593   20000000        1238         1231    0.2523   0.0534    0.0578
# 1  5294127   20000000        1240         1229    0.2523   0.0538    0.0593
# 2  5197910   20000000        1236         1233    0.2560   0.0528    0.0567
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000423     0.58    1.25  jnapq2W
# 1  0.000427     0.58    1.26  EqQj7M9
# 2  0.000413     0.57    1.25  2v5g38Z
#
#                                           expression concentrated_weight  \
# 0   zscore(ts_rank(implied_volatility_call_180, 3...                PASS
# 1   zscore(ts_rank(implied_volatility_call_150, 3...                PASS
# 2   zscore(ts_rank(implied_volatility_call_270, 3...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
# 1          PASS             FAIL        FAIL       FAIL
# 2          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING
# 1                    PASS         PASS        WARNING
# 2                    PASS         PASS        WARNING

# %% [markdown]
# ### To capture a comprehensive and nuanced view of market dynamics by combining medium-term volatility expectations with short-term price sensitivity signals, we utilised the option4 dataset which includes all datafields related to dispersion of call option.

# %%
selected_dataset =  hf.get_datafields(s, dataset_id='option4')
selected_dataset
# Out:
#                              id  \
# 0     opt4_122_call_dis_delta20
# 1     opt4_122_call_dis_delta25
# 2     opt4_122_call_dis_delta30
# 3     opt4_122_call_dis_delta35
# 4     opt4_122_call_dis_delta40
# ...                         ...
# 1191             opt4_vola_365d
# 1192             opt4_vola_547d
# 1193              opt4_vola_60d
# 1194             opt4_vola_730d
# 1195              opt4_vola_91d
#
#                                             description  \
# 0     The dispersion of a theoretical call option wi...
# 1     The dispersion of a theoretical call option wi...
# 2     The dispersion of a theoretical call option wi...
# 3     The dispersion of a theoretical call option wi...
# 4     The dispersion of a theoretical call option wi...
# ...                                                 ...
# 1191  Realized volatility, calculated over date rang...
# 1192  Realized volatility, calculated over date rang...
# 1193  Realized volatility, calculated over date rang...
# 1194  Realized volatility, calculated over date rang...
# 1195  Realized volatility, calculated over date rang...
#
#                                                 dataset category  \
# 0     {'id': 'option4', 'name': 'Implied Volatility ...   option
# 1     {'id': 'option4', 'name': 'Implied Volatility ...   option
# 2     {'id': 'option4', 'name': 'Implied Volatility ...   option
# 3     {'id': 'option4', 'name': 'Implied Volatility ...   option
# 4     {'id': 'option4', 'name': 'Implied Volatility ...   option
# ...                                                 ...      ...
# 1191  {'id': 'option4', 'name': 'Implied Volatility ...   option
# 1192  {'id': 'option4', 'name': 'Implied Volatility ...   option
# 1193  {'id': 'option4', 'name': 'Implied Volatility ...   option
# 1194  {'id': 'option4', 'name': 'Implied Volatility ...   option
# 1195  {'id': 'option4', 'name': 'Implied Volatility ...   option
#
#         subcategory region  delay universe    type  coverage turnover  \
# 0     option-option    USA      1  TOP3000  MATRIX    0.8362     None
# 1     option-option    USA      1  TOP3000  MATRIX    0.8362     None
# 2     option-option    USA      1  TOP3000  MATRIX    0.8362     None
# 3     option-option    USA      1  TOP3000  MATRIX    0.8362     None
# 4     option-option    USA      1  TOP3000  MATRIX    0.8362     None
# ...             ...    ...    ...      ...     ...       ...      ...
# 1191  option-option    USA      1  TOP3000  MATRIX    0.8397     None
# 1192  option-option    USA      1  TOP3000  MATRIX    0.8397     None
# 1193  option-option    USA      1  TOP3000  MATRIX    0.8396     None
# 1194  option-option    USA      1  TOP3000  MATRIX    0.8397     None
# 1195  option-option    USA      1  TOP3000  MATRIX    0.8396     None
#
#       userCount  alphaCount
# 0            46         414
# 1            36         122
# 2            15          52
# 3            14          88
# 4            50         340
# ...         ...         ...
# 1191         37         134
# 1192         49         334
# 1193         17          50
# 1194         29         108
# 1195         38         640
#
# [1196 rows x 13 columns]

# %% [markdown]
# ### Choosing the data fields with dispersion of call options and the alpha count greater than 50 in order to minimize the search space.

# %%
selected_datafields = selected_dataset.query("""
        id.str.contains('call_dis', case=False) == 1 &\
        50 <= alphaCount 
    """, engine='python')

selected_datafields = selected_datafields['id'].tolist()
print("The datafields with dispersion of call options having alpha count greater than 50 are : ")
display(selected_datafields)
# Out:
# The datafields with dispersion of call options having alpha count greater than 50 are :
# ['opt4_122_call_dis_delta20',
#  'opt4_122_call_dis_delta25',
#  'opt4_122_call_dis_delta30',
#  'opt4_122_call_dis_delta35',
#  'opt4_122_call_dis_delta40',
#  'opt4_122_call_dis_delta45',
#  'opt4_122_call_dis_delta50',
#  'opt4_122_call_dis_delta55',
#  'opt4_122_call_dis_delta60',
#  'opt4_122_call_dis_delta70',
#  'opt4_122_call_dis_delta80',
#  'opt4_152_call_dis_delta35',
#  'opt4_152_call_dis_delta40',
#  'opt4_152_call_dis_delta45',
#  'opt4_152_call_dis_delta60',
#  'opt4_152_call_dis_delta65',
#  'opt4_152_call_dis_delta75',
#  'opt4_182_call_dis_delta25',
#  'opt4_182_call_dis_delta30',
#  'opt4_182_call_dis_delta50',
#  'opt4_182_call_dis_delta55',
#  'opt4_182_call_dis_delta60',
#  'opt4_182_call_dis_delta75',
#  'opt4_182_call_dis_delta80',
#  'opt4_273_call_dis_delta80',
#  'opt4_30_call_dis_delta40',
#  'opt4_30_call_dis_delta50',
#  'opt4_30_call_dis_delta60',
#  'opt4_30_call_dis_delta80',
#  'opt4_365_call_dis_delta45',
#  'opt4_365_call_dis_delta60',
#  'opt4_365_call_dis_delta75',
#  'opt4_547_call_dis_delta35',
#  'opt4_547_call_dis_delta65',
#  'opt4_547_call_dis_delta75',
#  'opt4_60_call_dis_delta20',
#  'opt4_60_call_dis_delta40',
#  'opt4_60_call_dis_delta70',
#  'opt4_730_call_dis_delta40',
#  'opt4_730_call_dis_delta45',
#  'opt4_730_call_dis_delta50',
#  'opt4_730_call_dis_delta60',
#  'opt4_730_call_dis_delta65',
#  'opt4_730_call_dis_delta70',
#  'opt4_730_call_dis_delta75',
#  'opt4_730_call_dis_delta80',
#  'opt4_91_call_dis_delta50',
#  'opt4_91_call_dis_delta55',
#  'opt4_91_call_dis_delta70',
#  'opt4_91_call_dis_delta80']

# %%
print("Expressions used: ")
expression_list4 = result_st3['expression']
expression_list4
# Out:
# Expressions used:
# 0     zscore(ts_rank(implied_volatility_call_180, 3...
# 1     zscore(ts_rank(implied_volatility_call_150, 3...
# 2     zscore(ts_rank(implied_volatility_call_270, 3...
# Name: expression, dtype: object

# %%
final_exp_list = []
avg_fitness2 = []
avg_sharpe1 = []
for p in expression_list4:
    exp_list = [f' {x} + {p} ' for x  in selected_datafields]
    alph_list = [brain.generate_alpha(x, region= "USA",truncation = 0.08, universe = "TOP3000",pasteurization = 'ON', decay = 4 ,neutralization = "SUBINDUSTRY") for x in exp_list]
    result = brain.simulate_alpha_list_multi(s, alph_list)
    result_st = hf.prettify_result(result, detailed_tests_view=False)
    final_exp_list.append(result_st)
    display(result_st)
# Out:
# 100%|███████████████████████████████████████████| 17/17 [06:48<00:00, 24.01s/it]
# Average Sharpe for  zscore(ts_rank(implied_volatility_call_180, 360)) ) is: 1.3086000000000002
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   5685936   20000000        1184         1181    0.2576   0.0578    0.0577
# 1   5688644   20000000        1187         1180    0.2554   0.0578    0.0561
# 2   5652028   20000000        1187         1180    0.2552   0.0575    0.0555
# 3   5625010   20000000        1188         1179    0.2551   0.0572    0.0553
# 4   5708969   20000000        1187         1180    0.2554   0.0580    0.0567
# 5   5686179   20000000        1186         1180    0.2572   0.0578    0.0567
# 6   5636093   20000000        1187         1180    0.2552   0.0573    0.0554
# 7   5668225   20000000        1187         1180    0.2552   0.0576    0.0564
# 8   5648901   20000000        1187         1180    0.2552   0.0574    0.0561
# 9   5679241   20000000        1185         1182    0.2559   0.0577    0.0585
# 10  5616205   20000000        1187         1179    0.2577   0.0571    0.0559
# 11  5602861   20000000        1188         1179    0.2550   0.0570    0.0560
# 12  5602560   20000000        1188         1179    0.2551   0.0570    0.0552
# 13  5624656   20000000        1188         1179    0.2561   0.0572    0.0553
# 14  5596243   20000000        1187         1180    0.2561   0.0569    0.0554
# 15  5604422   20000000        1188         1179    0.2562   0.0570    0.0549
# 16  5577758   20000000        1188         1179    0.2550   0.0567    0.0562
# 17  5607096   20000000        1188         1179    0.2550   0.0570    0.0561
# 18  5586424   20000000        1188         1179    0.2552   0.0568    0.0553
# 19  5657421   20000000        1186         1181    0.2551   0.0575    0.0578
# 20  5587401   20000000        1188         1179    0.2552   0.0568    0.0554
# 21  5591965   20000000        1188         1179    0.2555   0.0569    0.0547
# 22  5593680   20000000        1188         1178    0.2563   0.0569    0.0548
# 23  5614592   20000000        1187         1178    0.2579   0.0571    0.0556
# 24  5595755   20000000        1188         1179    0.2551   0.0569    0.0547
# 25  5685328   20000000        1186         1181    0.2550   0.0578    0.0582
# 26  5660872   20000000        1188         1179    0.2575   0.0576    0.0558
# 27  5604016   20000000        1187         1179    0.2576   0.0570    0.0558
# 28  5653397   20000000        1186         1180    0.2552   0.0575    0.0572
# 29  5669507   20000000        1185         1182    0.2549   0.0576    0.0596
# 30  5584656   20000000        1187         1179    0.2556   0.0568    0.0556
# 31  5667535   20000000        1186         1181    0.2549   0.0576    0.0580
# 32  5673060   20000000        1186         1181    0.2550   0.0577    0.0575
# 33  5651887   20000000        1187         1180    0.2551   0.0575    0.0572
# 34  5620236   20000000        1187         1180    0.2553   0.0571    0.0556
# 35  5597656   20000000        1187         1180    0.2552   0.0569    0.0554
# 36  5633390   20000000        1186         1181    0.2548   0.0573    0.0583
# 37  5625135   20000000        1187         1180    0.2552   0.0572    0.0554
# 38  5613610   20000000        1188         1179    0.2552   0.0571    0.0552
# 39  5638602   20000000        1187         1179    0.2562   0.0573    0.0552
# 40  5579334   20000000        1187         1180    0.2563   0.0567    0.0556
# 41  5536421   20000000        1187         1180    0.2572   0.0563    0.0568
# 42  5601247   20000000        1186         1181    0.2548   0.0569    0.0589
# 43  5567435   20000000        1188         1179    0.2549   0.0566    0.0567
# 44  5551447   20000000        1187         1179    0.2583   0.0564    0.0558
# 45  5628324   20000000        1185         1182    0.2548   0.0572    0.0606
# 46  5624645   20000000        1184         1183    0.2558   0.0572    0.0622
# 47  5600859   20000000        1185         1182    0.2548   0.0569    0.0610
# 48  5472601   20000000        1187         1179    0.2594   0.0556    0.0548
# 49  5305160   20000000        1186         1179    0.2658   0.0539    0.0548
#
#       margin  fitness  sharpe alpha_id  \
# 0   0.000449     0.63    1.32  6RMkLGJ
# 1   0.000453     0.63    1.33  mqavGe2
# 2   0.000450     0.63    1.32  xevZp3l
# 3   0.000448     0.63    1.32  NnPZEkL
# 4   0.000455     0.63    1.33  aNap0Xv
# 5   0.000449     0.63    1.33  5LJXdG1
# 6   0.000449     0.63    1.32  aNapG92
# 7   0.000452     0.63    1.32  enajEPM
# 8   0.000450     0.63    1.32  Xka0MAm
# 9   0.000451     0.62    1.31  dnaGJYJ
# 10  0.000443     0.62    1.32  z5dV7pR
# 11  0.000447     0.62    1.31  OnW3daR
# 12  0.000447     0.62    1.31  qn7R2dv
# 13  0.000447     0.62    1.32  RNegxY1
# 14  0.000444     0.62    1.31  OnW3LKp
# 15  0.000445     0.62    1.31  GnmRjE5
# 16  0.000445     0.62    1.31  3E0NmkZ
# 17  0.000447     0.62    1.31  1oWM3Kk
# 18  0.000445     0.62    1.31  6RMk60P
# 19  0.000451     0.62    1.31  l7am1N5
# 20  0.000445     0.62    1.31  v5AQ7od
# 21  0.000445     0.62    1.31  OnW3d27
# 22  0.000444     0.62    1.31  3E0Nm20
# 23  0.000443     0.62    1.32  w5ordXp
# 24  0.000446     0.62    1.32  Jn89azn
# 25  0.000453     0.62    1.31  WNl5JxP
# 26  0.000447     0.62    1.32  rb7xM0d
# 27  0.000442     0.62    1.31  GnmR5m5
# 28  0.000450     0.62    1.31  jna7OMk
# 29  0.000452     0.62    1.30  7xYplRQ
# 30  0.000444     0.62    1.31  VXNWRpM
# 31  0.000452     0.62    1.31  v5AQbwd
# 32  0.000452     0.62    1.31  RNegoj1
# 33  0.000450     0.62    1.31  mqavlW5
# 34  0.000448     0.62    1.31  v5AQoXr
# 35  0.000446     0.62    1.31  OnW32XR
# 36  0.000450     0.62    1.30  z5dVn8R
# 37  0.000448     0.62    1.31  EqQdPpP
# 38  0.000447     0.62    1.31  Pn5Vm57
# 39  0.000448     0.62    1.32  Jn89J8e
# 40  0.000443     0.61    1.30  l7amNnl
# 41  0.000438     0.61    1.30  99ln5dq
# 42  0.000447     0.61    1.29  bNaw12r
# 43  0.000444     0.61    1.30  3E0Nmx0
# 44  0.000437     0.61    1.30  WNl5xpx
# 45  0.000449     0.61    1.28  knaA96d
# 46  0.000447     0.60    1.27  z5dV7wK
# 47  0.000447     0.60    1.27  YNaeYOR
# 48  0.000429     0.60    1.29  VXNWrK0
# 49  0.000406     0.57    1.27  AnxAXKl
#
#                                            expression concentrated_weight  \
# 0    opt4_30_call_dis_delta40 +  zscore(ts_rank(im...                PASS
# 1    opt4_91_call_dis_delta55 +  zscore(ts_rank(im...                PASS
# 2    opt4_182_call_dis_delta50 +  zscore(ts_rank(i...                PASS
# 3    opt4_547_call_dis_delta65 +  zscore(ts_rank(i...                PASS
# 4    opt4_91_call_dis_delta50 +  zscore(ts_rank(im...                PASS
# 5    opt4_30_call_dis_delta50 +  zscore(ts_rank(im...                PASS
# 6    opt4_122_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 7    opt4_122_call_dis_delta50 +  zscore(ts_rank(i...                PASS
# 8    opt4_122_call_dis_delta55 +  zscore(ts_rank(i...                PASS
# 9    opt4_60_call_dis_delta40 +  zscore(ts_rank(im...                PASS
# 10   opt4_30_call_dis_delta60 +  zscore(ts_rank(im...                PASS
# 11   opt4_365_call_dis_delta45 +  zscore(ts_rank(i...                PASS
# 12   opt4_365_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 13   opt4_365_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 14   opt4_91_call_dis_delta70 +  zscore(ts_rank(im...                PASS
# 15   opt4_547_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 16   opt4_730_call_dis_delta40 +  zscore(ts_rank(i...                PASS
# 17   opt4_730_call_dis_delta45 +  zscore(ts_rank(i...                PASS
# 18   opt4_730_call_dis_delta50 +  zscore(ts_rank(i...                PASS
# 19   opt4_122_call_dis_delta40 +  zscore(ts_rank(i...                PASS
# 20   opt4_730_call_dis_delta65 +  zscore(ts_rank(i...                PASS
# 21   opt4_730_call_dis_delta70 +  zscore(ts_rank(i...                PASS
# 22   opt4_730_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 23   opt4_730_call_dis_delta80 +  zscore(ts_rank(i...                PASS
# 24   opt4_730_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 25   opt4_122_call_dis_delta35 +  zscore(ts_rank(i...                PASS
# 26   opt4_273_call_dis_delta80 +  zscore(ts_rank(i...                PASS
# 27   opt4_182_call_dis_delta80 +  zscore(ts_rank(i...                PASS
# 28   opt4_122_call_dis_delta45 +  zscore(ts_rank(i...                PASS
# 29   opt4_122_call_dis_delta30 +  zscore(ts_rank(i...                PASS
# 30   opt4_122_call_dis_delta70 +  zscore(ts_rank(i...                PASS
# 31   opt4_152_call_dis_delta35 +  zscore(ts_rank(i...                PASS
# 32   opt4_152_call_dis_delta40 +  zscore(ts_rank(i...                PASS
# 33   opt4_152_call_dis_delta45 +  zscore(ts_rank(i...                PASS
# 34   opt4_152_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 35   opt4_152_call_dis_delta65 +  zscore(ts_rank(i...                PASS
# 36   opt4_182_call_dis_delta30 +  zscore(ts_rank(i...                PASS
# 37   opt4_182_call_dis_delta55 +  zscore(ts_rank(i...                PASS
# 38   opt4_182_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 39   opt4_182_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 40   opt4_152_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 41   opt4_60_call_dis_delta70 +  zscore(ts_rank(im...                PASS
# 42   opt4_182_call_dis_delta25 +  zscore(ts_rank(i...                PASS
# 43   opt4_547_call_dis_delta35 +  zscore(ts_rank(i...                PASS
# 44   opt4_122_call_dis_delta80 +  zscore(ts_rank(i...                PASS
# 45   opt4_122_call_dis_delta25 +  zscore(ts_rank(i...                PASS
# 46   opt4_60_call_dis_delta20 +  zscore(ts_rank(im...                PASS
# 47   opt4_122_call_dis_delta20 +  zscore(ts_rank(i...                PASS
# 48   opt4_91_call_dis_delta80 +  zscore(ts_rank(im...                PASS
# 49   opt4_30_call_dis_delta80 +  zscore(ts_rank(im...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        FAIL       FAIL
# 1           PASS             FAIL        FAIL       FAIL
# 2           PASS             FAIL        FAIL       FAIL
# 3           PASS             FAIL        FAIL       FAIL
# 4           PASS             FAIL        FAIL       FAIL
# 5           PASS             FAIL        FAIL       FAIL
# 6           PASS             FAIL        FAIL       FAIL
# 7           PASS             FAIL        FAIL       FAIL
# 8           PASS             FAIL        FAIL       FAIL
# 9           PASS             FAIL        FAIL       FAIL
# 10          PASS             FAIL        FAIL       FAIL
# 11          PASS             FAIL        FAIL       FAIL
# 12          PASS             FAIL        FAIL       FAIL
# 13          PASS             FAIL        FAIL       FAIL
# 14          PASS             FAIL        FAIL       FAIL
# 15          PASS             FAIL        FAIL       FAIL
# 16          PASS             FAIL        FAIL       FAIL
# 17          PASS             FAIL        FAIL       FAIL
# 18          PASS             FAIL        FAIL       FAIL
# 19          PASS             FAIL        FAIL       FAIL
# 20          PASS             FAIL        FAIL       FAIL
# 21          PASS             FAIL        FAIL       FAIL
# 22          PASS             FAIL        FAIL       FAIL
# 23          PASS             FAIL        FAIL       FAIL
# 24          PASS             FAIL        FAIL       FAIL
# 25          PASS             FAIL        FAIL       FAIL
# 26          PASS             FAIL        FAIL       FAIL
# 27          PASS             FAIL        FAIL       FAIL
# 28          PASS             FAIL        FAIL       FAIL
# 29          PASS             FAIL        FAIL       FAIL
# 30          PASS             FAIL        FAIL       FAIL
# 31          PASS             FAIL        FAIL       FAIL
# 32          PASS             FAIL        FAIL       FAIL
# 33          PASS             FAIL        FAIL       FAIL
# 34          PASS             FAIL        FAIL       FAIL
# 35          PASS             FAIL        FAIL       FAIL
# 36          PASS             FAIL        FAIL       FAIL
# 37          PASS             FAIL        FAIL       FAIL
# 38          PASS             FAIL        FAIL       FAIL
# 39          PASS             FAIL        FAIL       FAIL
# 40          PASS             FAIL        FAIL       FAIL
# 41          PASS             FAIL        FAIL       FAIL
# 42          PASS             FAIL        FAIL       FAIL
# 43          PASS             FAIL        FAIL       FAIL
# 44          PASS             FAIL        FAIL       FAIL
# 45          PASS             FAIL        FAIL       FAIL
# 46          PASS             FAIL        FAIL       FAIL
# 47          PASS             FAIL        FAIL       FAIL
# 48          PASS             FAIL        FAIL       FAIL
# 49          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover matches_themes
# 0                     PASS         PASS        WARNING
# 1                     PASS         PASS        WARNING
# 2                     PASS         PASS        WARNING
# 3                     PASS         PASS        WARNING
# 4                     PASS         PASS        WARNING
# 5                     PASS         PASS        WARNING
# 6                     PASS         PASS        WARNING
# 7                     PASS         PASS        WARNING
# 8                     PASS         PASS        WARNING
# 9                     PASS         PASS        WARNING
# 10                    PASS         PASS        WARNING
# 11                    PASS         PASS        WARNING
# 12                    PASS         PASS        WARNING
# 13                    PASS         PASS        WARNING
# 14                    PASS         PASS        WARNING
# 15                    PASS         PASS        WARNING
# 16                    PASS         PASS        WARNING
# 17                    PASS         PASS        WARNING
# 18                    PASS         PASS        WARNING
# 19                    PASS         PASS        WARNING
# 20                    PASS         PASS        WARNING
# 21                    PASS         PASS        WARNING
# 22                    PASS         PASS        WARNING
# 23                    PASS         PASS        WARNING
# 24                    PASS         PASS        WARNING
# 25                    PASS         PASS        WARNING
# 26                    PASS         PASS        WARNING
# 27                    PASS         PASS        WARNING
# 28                    PASS         PASS        WARNING
# 29                    PASS         PASS        WARNING
# 30                    PASS         PASS        WARNING
# 31                    PASS         PASS        WARNING
# 32                    PASS         PASS        WARNING
# 33                    PASS         PASS        WARNING
# 34                    PASS         PASS        WARNING
# 35                    PASS         PASS        WARNING
# 36                    PASS         PASS        WARNING
# 37                    PASS         PASS        WARNING
# 38                    PASS         PASS        WARNING
# 39                    PASS         PASS        WARNING
# 40                    PASS         PASS        WARNING
# 41                    PASS         PASS        WARNING
# 42                    PASS         PASS        WARNING
# 43                    PASS         PASS        WARNING
# 44                    PASS         PASS        WARNING
# 45                    PASS         PASS        WARNING
# 46                    PASS         PASS        WARNING
# 47                    PASS         PASS        WARNING
# 48                    PASS         PASS        WARNING
# 49                    PASS         PASS        WARNING
# 100%|███████████████████████████████████████████| 17/17 [06:23<00:00, 22.55s/it]
# Average Sharpe for  zscore(ts_rank(implied_volatility_call_150, 360)) ) is: 1.3246000000000004
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   5771793   20000000        1186         1180    0.2577   0.0587    0.0595
# 1   5753728   20000000        1188         1179    0.2552   0.0585    0.0594
# 2   5773288   20000000        1187         1178    0.2574   0.0587    0.0584
# 3   5740349   20000000        1189         1177    0.2577   0.0584    0.0577
# 4   5708989   20000000        1190         1177    0.2553   0.0580    0.0571
# 5   5732811   20000000        1189         1178    0.2553   0.0583    0.0573
# 6   5759058   20000000        1186         1180    0.2560   0.0586    0.0603
# 7   5733704   20000000        1188         1179    0.2552   0.0583    0.0590
# 8   5699407   20000000        1188         1177    0.2578   0.0579    0.0577
# 9   5768837   20000000        1188         1179    0.2555   0.0587    0.0580
# 10  5732460   20000000        1188         1179    0.2553   0.0583    0.0590
# 11  5789463   20000000        1188         1179    0.2555   0.0589    0.0586
# 12  5749252   20000000        1188         1179    0.2554   0.0585    0.0583
# 13  5729774   20000000        1188         1178    0.2554   0.0583    0.0579
# 14  5679691   20000000        1189         1178    0.2561   0.0577    0.0572
# 15  5688317   20000000        1190         1177    0.2552   0.0578    0.0570
# 16  5707652   20000000        1189         1177    0.2563   0.0580    0.0571
# 17  5654291   20000000        1189         1178    0.2550   0.0575    0.0585
# 18  5683099   20000000        1189         1177    0.2563   0.0578    0.0568
# 19  5679826   20000000        1189         1177    0.2565   0.0577    0.0566
# 20  5675353   20000000        1190         1177    0.2557   0.0577    0.0566
# 21  5666214   20000000        1189         1177    0.2551   0.0576    0.0581
# 22  5691114   20000000        1189         1177    0.2551   0.0579    0.0579
# 23  5665648   20000000        1190         1177    0.2552   0.0576    0.0572
# 24  5686778   20000000        1189         1178    0.2551   0.0578    0.0579
# 25  5698763   20000000        1189         1177    0.2581   0.0579    0.0575
# 26  5670268   20000000        1190         1177    0.2553   0.0576    0.0572
# 27  5678161   20000000        1190         1177    0.2553   0.0577    0.0566
# 28  5766458   20000000        1187         1180    0.2551   0.0586    0.0601
# 29  5656286   20000000        1189         1178    0.2564   0.0575    0.0574
# 30  5683639   20000000        1189         1178    0.2578   0.0578    0.0577
# 31  5719146   20000000        1189         1178    0.2563   0.0581    0.0570
# 32  5693670   20000000        1189         1178    0.2553   0.0579    0.0570
# 33  5712079   20000000        1189         1178    0.2553   0.0581    0.0572
# 34  5717025   20000000        1189         1178    0.2553   0.0581    0.0572
# 35  5717477   20000000        1188         1179    0.2549   0.0581    0.0601
# 36  5749399   20000000        1187         1180    0.2550   0.0585    0.0615
# 37  5667151   20000000        1189         1178    0.2557   0.0576    0.0575
# 38  5740542   20000000        1187         1180    0.2552   0.0584    0.0596
# 39  5677106   20000000        1189         1178    0.2554   0.0577    0.0573
# 40  5699277   20000000        1189         1178    0.2554   0.0579    0.0574
# 41  5747829   20000000        1188         1179    0.2551   0.0584    0.0598
# 42  5629504   20000000        1189         1178    0.2584   0.0572    0.0576
# 43  5686392   20000000        1188         1179    0.2549   0.0578    0.0607
# 44  5619367   20000000        1188         1178    0.2572   0.0571    0.0587
# 45  5710585   20000000        1186         1180    0.2549   0.0581    0.0624
# 46  5684601   20000000        1186         1180    0.2548   0.0578    0.0629
# 47  5548991   20000000        1189         1178    0.2595   0.0564    0.0567
# 48  5705983   20000000        1185         1182    0.2559   0.0580    0.0641
# 49  5387959   20000000        1187         1178    0.2659   0.0548    0.0566
#
#       margin  fitness  sharpe alpha_id  \
# 0   0.000455     0.64    1.34  3E0N8qZ
# 1   0.000459     0.64    1.33  gma22Km
# 2   0.000456     0.64    1.35  5LJXP86
# 3   0.000453     0.64    1.34  1oWMrYk
# 4   0.000455     0.64    1.34  dnaGNjK
# 5   0.000457     0.64    1.33  aNappx1
# 6   0.000457     0.64    1.33  aNap57O
# 7   0.000457     0.64    1.33  0APJJdp
# 8   0.000449     0.64    1.34  qn7RQMO
# 9   0.000459     0.64    1.34  EqQ9Z51
# 10  0.000457     0.64    1.33  RNegOzn
# 11  0.000461     0.64    1.34  aNa5rr9
# 12  0.000458     0.64    1.33  bNawmrK
# 13  0.000456     0.64    1.33  onadbGm
# 14  0.000451     0.63    1.33  rb7Z1Jm
# 15  0.000453     0.63    1.33  EqQd9K1
# 16  0.000453     0.63    1.33  VXNWA8Y
# 17  0.000451     0.63    1.32  Kng1WLk
# 18  0.000451     0.63    1.33  enajX9p
# 19  0.000450     0.63    1.33  2v531Mb
# 20  0.000451     0.63    1.33  Xkadjm0
# 21  0.000452     0.63    1.32  Mb6rJ1o
# 22  0.000454     0.63    1.33  onadxbl
# 23  0.000451     0.63    1.33  RNegGOb
# 24  0.000453     0.63    1.33  EqQd95P
# 25  0.000449     0.63    1.33  Xkadjja
# 26  0.000452     0.63    1.33  5LJPZn5
# 27  0.000452     0.63    1.33  LnKQ0v2
# 28  0.000460     0.63    1.32  GnmR2Kx
# 29  0.000449     0.63    1.32  Jn899mx
# 30  0.000448     0.63    1.32  0APJJ2p
# 31  0.000454     0.63    1.33  ZjaJJvx
# 32  0.000453     0.63    1.33  xevZZpg
# 33  0.000455     0.63    1.33  AnxAAvQ
# 34  0.000455     0.63    1.33  1oWM8K6
# 35  0.000456     0.63    1.32  Xka00Jl
# 36  0.000458     0.63    1.31  gma2lW0
# 37  0.000451     0.63    1.32  99lnnL9
# 38  0.000457     0.63    1.32  z5dVx2V
# 39  0.000452     0.63    1.32  8ONwwra
# 40  0.000454     0.63    1.33  YNaeemM
# 41  0.000458     0.63    1.32  0APJJ0G
# 42  0.000443     0.62    1.31  Pn5VVdM
# 43  0.000454     0.62    1.31  l7amm2A
# 44  0.000444     0.62    1.32  xevZJjl
# 45  0.000456     0.62    1.30  99lneEx
# 46  0.000454     0.61    1.29  dnaGMKj
# 47  0.000435     0.61    1.30  5LJPZaM
# 48  0.000453     0.61    1.29  nnaELKz
# 49  0.000412     0.59    1.29  mqavEL1
#
#                                            expression concentrated_weight  \
# 0    opt4_30_call_dis_delta40 +  zscore(ts_rank(im...                PASS
# 1    opt4_152_call_dis_delta40 +  zscore(ts_rank(i...                PASS
# 2    opt4_30_call_dis_delta50 +  zscore(ts_rank(im...                PASS
# 3    opt4_273_call_dis_delta80 +  zscore(ts_rank(i...                PASS
# 4    opt4_547_call_dis_delta65 +  zscore(ts_rank(i...                PASS
# 5    opt4_182_call_dis_delta50 +  zscore(ts_rank(i...                PASS
# 6    opt4_60_call_dis_delta40 +  zscore(ts_rank(im...                PASS
# 7    opt4_152_call_dis_delta45 +  zscore(ts_rank(i...                PASS
# 8    opt4_30_call_dis_delta60 +  zscore(ts_rank(im...                PASS
# 9    opt4_91_call_dis_delta55 +  zscore(ts_rank(im...                PASS
# 10   opt4_122_call_dis_delta45 +  zscore(ts_rank(i...                PASS
# 11   opt4_91_call_dis_delta50 +  zscore(ts_rank(im...                PASS
# 12   opt4_122_call_dis_delta50 +  zscore(ts_rank(i...                PASS
# 13   opt4_122_call_dis_delta55 +  zscore(ts_rank(i...                PASS
# 14   opt4_91_call_dis_delta70 +  zscore(ts_rank(im...                PASS
# 15   opt4_365_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 16   opt4_365_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 17   opt4_547_call_dis_delta35 +  zscore(ts_rank(i...                PASS
# 18   opt4_547_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 19   opt4_730_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 20   opt4_730_call_dis_delta70 +  zscore(ts_rank(i...                PASS
# 21   opt4_730_call_dis_delta40 +  zscore(ts_rank(i...                PASS
# 22   opt4_730_call_dis_delta45 +  zscore(ts_rank(i...                PASS
# 23   opt4_730_call_dis_delta50 +  zscore(ts_rank(i...                PASS
# 24   opt4_365_call_dis_delta45 +  zscore(ts_rank(i...                PASS
# 25   opt4_730_call_dis_delta80 +  zscore(ts_rank(i...                PASS
# 26   opt4_730_call_dis_delta65 +  zscore(ts_rank(i...                PASS
# 27   opt4_730_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 28   opt4_122_call_dis_delta35 +  zscore(ts_rank(i...                PASS
# 29   opt4_152_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 30   opt4_182_call_dis_delta80 +  zscore(ts_rank(i...                PASS
# 31   opt4_182_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 32   opt4_182_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 33   opt4_182_call_dis_delta55 +  zscore(ts_rank(i...                PASS
# 34   opt4_122_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 35   opt4_182_call_dis_delta30 +  zscore(ts_rank(i...                PASS
# 36   opt4_122_call_dis_delta30 +  zscore(ts_rank(i...                PASS
# 37   opt4_122_call_dis_delta70 +  zscore(ts_rank(i...                PASS
# 38   opt4_122_call_dis_delta40 +  zscore(ts_rank(i...                PASS
# 39   opt4_152_call_dis_delta65 +  zscore(ts_rank(i...                PASS
# 40   opt4_152_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 41   opt4_152_call_dis_delta35 +  zscore(ts_rank(i...                PASS
# 42   opt4_122_call_dis_delta80 +  zscore(ts_rank(i...                PASS
# 43   opt4_182_call_dis_delta25 +  zscore(ts_rank(i...                PASS
# 44   opt4_60_call_dis_delta70 +  zscore(ts_rank(im...                PASS
# 45   opt4_122_call_dis_delta25 +  zscore(ts_rank(i...                PASS
# 46   opt4_122_call_dis_delta20 +  zscore(ts_rank(i...                PASS
# 47   opt4_91_call_dis_delta80 +  zscore(ts_rank(im...                PASS
# 48   opt4_60_call_dis_delta20 +  zscore(ts_rank(im...                PASS
# 49   opt4_30_call_dis_delta80 +  zscore(ts_rank(im...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        FAIL       FAIL
# 1           PASS             FAIL        FAIL       FAIL
# 2           PASS             FAIL        FAIL       FAIL
# 3           PASS             FAIL        FAIL       FAIL
# 4           PASS             FAIL        FAIL       FAIL
# 5           PASS             FAIL        FAIL       FAIL
# 6           PASS             FAIL        FAIL       FAIL
# 7           PASS             FAIL        FAIL       FAIL
# 8           PASS             FAIL        FAIL       FAIL
# 9           PASS             FAIL        FAIL       FAIL
# 10          PASS             FAIL        FAIL       FAIL
# 11          PASS             FAIL        FAIL       FAIL
# 12          PASS             FAIL        FAIL       FAIL
# 13          PASS             FAIL        FAIL       FAIL
# 14          PASS             FAIL        FAIL       FAIL
# 15          PASS             FAIL        FAIL       FAIL
# 16          PASS             FAIL        FAIL       FAIL
# 17          PASS             FAIL        FAIL       FAIL
# 18          PASS             FAIL        FAIL       FAIL
# 19          PASS             FAIL        FAIL       FAIL
# 20          PASS             FAIL        FAIL       FAIL
# 21          PASS             FAIL        FAIL       FAIL
# 22          PASS             FAIL        FAIL       FAIL
# 23          PASS             FAIL        FAIL       FAIL
# 24          PASS             FAIL        FAIL       FAIL
# 25          PASS             FAIL        FAIL       FAIL
# 26          PASS             FAIL        FAIL       FAIL
# 27          PASS             FAIL        FAIL       FAIL
# 28          PASS             FAIL        FAIL       FAIL
# 29          PASS             FAIL        FAIL       FAIL
# 30          PASS             FAIL        FAIL       FAIL
# 31          PASS             FAIL        FAIL       FAIL
# 32          PASS             FAIL        FAIL       FAIL
# 33          PASS             FAIL        FAIL       FAIL
# 34          PASS             FAIL        FAIL       FAIL
# 35          PASS             FAIL        FAIL       FAIL
# 36          PASS             FAIL        FAIL       FAIL
# 37          PASS             FAIL        FAIL       FAIL
# 38          PASS             FAIL        FAIL       FAIL
# 39          PASS             FAIL        FAIL       FAIL
# 40          PASS             FAIL        FAIL       FAIL
# 41          PASS             FAIL        FAIL       FAIL
# 42          PASS             FAIL        FAIL       FAIL
# 43          PASS             FAIL        FAIL       FAIL
# 44          PASS             FAIL        FAIL       FAIL
# 45          PASS             FAIL        FAIL       FAIL
# 46          PASS             FAIL        FAIL       FAIL
# 47          PASS             FAIL        FAIL       FAIL
# 48          PASS             FAIL        FAIL       FAIL
# 49          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover matches_themes
# 0                     PASS         PASS        WARNING
# 1                     PASS         PASS        WARNING
# 2                     PASS         PASS        WARNING
# 3                     PASS         PASS        WARNING
# 4                     PASS         PASS        WARNING
# 5                     PASS         PASS        WARNING
# 6                     PASS         PASS        WARNING
# 7                     PASS         PASS        WARNING
# 8                     PASS         PASS        WARNING
# 9                     PASS         PASS        WARNING
# 10                    PASS         PASS        WARNING
# 11                    PASS         PASS        WARNING
# 12                    PASS         PASS        WARNING
# 13                    PASS         PASS        WARNING
# 14                    PASS         PASS        WARNING
# 15                    PASS         PASS        WARNING
# 16                    PASS         PASS        WARNING
# 17                    PASS         PASS        WARNING
# 18                    PASS         PASS        WARNING
# 19                    PASS         PASS        WARNING
# 20                    PASS         PASS        WARNING
# 21                    PASS         PASS        WARNING
# 22                    PASS         PASS        WARNING
# 23                    PASS         PASS        WARNING
# 24                    PASS         PASS        WARNING
# 25                    PASS         PASS        WARNING
# 26                    PASS         PASS        WARNING
# 27                    PASS         PASS        WARNING
# 28                    PASS         PASS        WARNING
# 29                    PASS         PASS        WARNING
# 30                    PASS         PASS        WARNING
# 31                    PASS         PASS        WARNING
# 32                    PASS         PASS        WARNING
# 33                    PASS         PASS        WARNING
# 34                    PASS         PASS        WARNING
# 35                    PASS         PASS        WARNING
# 36                    PASS         PASS        WARNING
# 37                    PASS         PASS        WARNING
# 38                    PASS         PASS        WARNING
# 39                    PASS         PASS        WARNING
# 40                    PASS         PASS        WARNING
# 41                    PASS         PASS        WARNING
# 42                    PASS         PASS        WARNING
# 43                    PASS         PASS        WARNING
# 44                    PASS         PASS        WARNING
# 45                    PASS         PASS        WARNING
# 46                    PASS         PASS        WARNING
# 47                    PASS         PASS        WARNING
# 48                    PASS         PASS        WARNING
# 49                    PASS         PASS        WARNING
# 100%|███████████████████████████████████████████| 17/17 [07:23<00:00, 26.09s/it]
# Average Sharpe for  zscore(ts_rank(implied_volatility_call_270, 360)) ) is: 1.3034000000000001
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   5606962   20000000        1182         1183    0.2613   0.0570    0.0572
# 1   5587032   20000000        1184         1182    0.2609   0.0568    0.0561
# 2   5613552   20000000        1185         1182    0.2591   0.0571    0.0555
# 3   5636666   20000000        1184         1182    0.2591   0.0573    0.0560
# 4   5548718   20000000        1186         1181    0.2588   0.0564    0.0547
# 5   5546823   20000000        1186         1181    0.2598   0.0564    0.0546
# 6   5543604   20000000        1185         1182    0.2588   0.0564    0.0546
# 7   5581140   20000000        1184         1183    0.2588   0.0567    0.0571
# 8   5535739   20000000        1184         1181    0.2614   0.0563    0.0553
# 9   5514978   20000000        1185         1182    0.2588   0.0561    0.0553
# 10  5529066   20000000        1185         1181    0.2588   0.0562    0.0545
# 11  5605240   20000000        1183         1183    0.2587   0.0570    0.0577
# 12  5608264   20000000        1183         1184    0.2596   0.0570    0.0579
# 13  5569681   20000000        1185         1181    0.2612   0.0566    0.0552
# 14  5515198   20000000        1186         1181    0.2592   0.0561    0.0540
# 15  5519359   20000000        1185         1181    0.2588   0.0561    0.0554
# 16  5512432   20000000        1185         1181    0.2589   0.0560    0.0547
# 17  5517794   20000000        1186         1181    0.2589   0.0561    0.0541
# 18  5539042   20000000        1185         1181    0.2616   0.0563    0.0549
# 19  5520023   20000000        1185         1182    0.2599   0.0561    0.0548
# 20  5510372   20000000        1186         1181    0.2589   0.0560    0.0548
# 21  5566162   20000000        1185         1181    0.2599   0.0566    0.0546
# 22  5545928   20000000        1185         1182    0.2589   0.0564    0.0547
# 23  5568596   20000000        1184         1183    0.2588   0.0566    0.0566
# 24  5576867   20000000        1184         1183    0.2589   0.0567    0.0565
# 25  5597872   20000000        1184         1182    0.2589   0.0569    0.0558
# 26  5573073   20000000        1185         1182    0.2589   0.0567    0.0554
# 27  5548520   20000000        1185         1182    0.2589   0.0564    0.0547
# 28  5579256   20000000        1185         1182    0.2589   0.0567    0.0548
# 29  5599323   20000000        1184         1183    0.2587   0.0569    0.0569
# 30  5592651   20000000        1184         1183    0.2587   0.0569    0.0574
# 31  5551237   20000000        1185         1182    0.2589   0.0564    0.0550
# 32  5525981   20000000        1185         1182    0.2589   0.0562    0.0547
# 33  5555073   20000000        1184         1183    0.2586   0.0565    0.0576
# 34  5519038   20000000        1185         1181    0.2599   0.0561    0.0543
# 35  5501529   20000000        1185         1181    0.2600   0.0559    0.0542
# 36  5521745   20000000        1184         1183    0.2585   0.0561    0.0583
# 37  5530837   20000000        1185         1181    0.2613   0.0562    0.0552
# 38  5506963   20000000        1185         1182    0.2600   0.0560    0.0549
# 39  5580793   20000000        1183         1184    0.2587   0.0567    0.0590
# 40  5493544   20000000        1185         1182    0.2594   0.0559    0.0550
# 41  5475587   20000000        1185         1182    0.2620   0.0557    0.0550
# 42  5485355   20000000        1185         1181    0.2588   0.0558    0.0556
# 43  5473606   20000000        1185         1182    0.2586   0.0556    0.0561
# 44  5550129   20000000        1181         1185    0.2595   0.0564    0.0615
# 45  5536023   20000000        1183         1184    0.2585   0.0563    0.0600
# 46  5521735   20000000        1183         1184    0.2585   0.0561    0.0605
# 47  5447112   20000000        1185         1182    0.2609   0.0554    0.0562
# 48  5399340   20000000        1185         1181    0.2632   0.0549    0.0542
# 49  5223581   20000000        1184         1181    0.2694   0.0531    0.0542
#
#       margin  fitness  sharpe alpha_id  \
# 0   0.000436     0.62    1.32  7xYe821
# 1   0.000435     0.62    1.32  xevJAEl
# 2   0.000441     0.62    1.32  GnmZPAJ
# 3   0.000442     0.62    1.32  Jn86qwA
# 4   0.000436     0.62    1.32  NnPYxWg
# 5   0.000434     0.61    1.31  Mb6JMoz
# 6   0.000435     0.61    1.31  LnK0LK2
# 7   0.000438     0.61    1.30  YNaRj3w
# 8   0.000431     0.61    1.32  YNaRLLw
# 9   0.000433     0.61    1.30  mqaEww6
# 10  0.000434     0.61    1.31  WNlv16O
# 11  0.000441     0.61    1.30  WNlvErQ
# 12  0.000439     0.61    1.31  Qn0wZvX
# 13  0.000434     0.61    1.31  GnmZr73
# 14  0.000433     0.61    1.31  Jn86M3W
# 15  0.000434     0.61    1.31  OnWlQRJ
# 16  0.000433     0.61    1.31  ZjaOPgd
# 17  0.000433     0.61    1.31  8ONM5VX
# 18  0.000431     0.61    1.31  KngW30z
# 19  0.000432     0.61    1.31  5LJPx86
# 20  0.000433     0.61    1.31  KngWlVN
# 21  0.000436     0.61    1.31  Qn0wP0w
# 22  0.000436     0.61    1.31  WNlvjeZ
# 23  0.000437     0.61    1.31  KngWPeg
# 24  0.000438     0.61    1.31  nnaL1G3
# 25  0.000440     0.61    1.31  Jn86VAO
# 26  0.000438     0.61    1.31  YNaRjVv
# 27  0.000436     0.61    1.31  w5o08dQ
# 28  0.000438     0.61    1.31  8ONM8PX
# 29  0.000440     0.61    1.31  1oWrYvz
# 30  0.000440     0.61    1.30  pna9woo
# 31  0.000436     0.61    1.31  5LJP8R5
# 32  0.000434     0.61    1.31  YNaRP2l
# 33  0.000437     0.61    1.30  Qn0wPKW
# 34  0.000432     0.60    1.30  aNa5j2x
# 35  0.000430     0.60    1.30  l7aopgN
# 36  0.000434     0.60    1.28  w5o0pnv
# 37  0.000430     0.60    1.30  dnaN59X
# 38  0.000431     0.60    1.30  knazq1O
# 39  0.000439     0.60    1.29  LnK0P21
# 40  0.000431     0.60    1.30  5LJP83n
# 41  0.000425     0.60    1.30  Mb6JPqo
# 42  0.000431     0.60    1.30  YNaRL1v
# 43  0.000430     0.60    1.29  pna9YAb
# 44  0.000435     0.59    1.27  EqQ9O0L
# 45  0.000435     0.59    1.27  z5dlvLo
# 46  0.000434     0.59    1.27  jnaq5MQ
# 47  0.000425     0.59    1.29  0AP1OY8
# 48  0.000417     0.59    1.29  Jn86qjn
# 49  0.000394     0.56    1.27  bNaeGGq
#
#                                            expression concentrated_weight  \
# 0    opt4_30_call_dis_delta40 +  zscore(ts_rank(im...                PASS
# 1    opt4_30_call_dis_delta50 +  zscore(ts_rank(im...                PASS
# 2    opt4_91_call_dis_delta55 +  zscore(ts_rank(im...                PASS
# 3    opt4_91_call_dis_delta50 +  zscore(ts_rank(im...                PASS
# 4    opt4_547_call_dis_delta65 +  zscore(ts_rank(i...                PASS
# 5    opt4_365_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 6    opt4_182_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 7    opt4_122_call_dis_delta40 +  zscore(ts_rank(i...                PASS
# 8    opt4_30_call_dis_delta60 +  zscore(ts_rank(im...                PASS
# 9    opt4_365_call_dis_delta45 +  zscore(ts_rank(i...                PASS
# 10   opt4_365_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 11   opt4_122_call_dis_delta35 +  zscore(ts_rank(i...                PASS
# 12   opt4_60_call_dis_delta40 +  zscore(ts_rank(im...                PASS
# 13   opt4_273_call_dis_delta80 +  zscore(ts_rank(i...                PASS
# 14   opt4_730_call_dis_delta70 +  zscore(ts_rank(i...                PASS
# 15   opt4_730_call_dis_delta45 +  zscore(ts_rank(i...                PASS
# 16   opt4_730_call_dis_delta50 +  zscore(ts_rank(i...                PASS
# 17   opt4_730_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 18   opt4_730_call_dis_delta80 +  zscore(ts_rank(i...                PASS
# 19   opt4_91_call_dis_delta70 +  zscore(ts_rank(im...                PASS
# 20   opt4_730_call_dis_delta65 +  zscore(ts_rank(i...                PASS
# 21   opt4_182_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 22   opt4_182_call_dis_delta55 +  zscore(ts_rank(i...                PASS
# 23   opt4_152_call_dis_delta45 +  zscore(ts_rank(i...                PASS
# 24   opt4_122_call_dis_delta45 +  zscore(ts_rank(i...                PASS
# 25   opt4_122_call_dis_delta50 +  zscore(ts_rank(i...                PASS
# 26   opt4_122_call_dis_delta55 +  zscore(ts_rank(i...                PASS
# 27   opt4_122_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 28   opt4_182_call_dis_delta50 +  zscore(ts_rank(i...                PASS
# 29   opt4_152_call_dis_delta40 +  zscore(ts_rank(i...                PASS
# 30   opt4_152_call_dis_delta35 +  zscore(ts_rank(i...                PASS
# 31   opt4_152_call_dis_delta60 +  zscore(ts_rank(i...                PASS
# 32   opt4_152_call_dis_delta65 +  zscore(ts_rank(i...                PASS
# 33   opt4_182_call_dis_delta30 +  zscore(ts_rank(i...                PASS
# 34   opt4_547_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 35   opt4_730_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 36   opt4_182_call_dis_delta25 +  zscore(ts_rank(i...                PASS
# 37   opt4_182_call_dis_delta80 +  zscore(ts_rank(i...                PASS
# 38   opt4_152_call_dis_delta75 +  zscore(ts_rank(i...                PASS
# 39   opt4_122_call_dis_delta30 +  zscore(ts_rank(i...                PASS
# 40   opt4_122_call_dis_delta70 +  zscore(ts_rank(i...                PASS
# 41   opt4_122_call_dis_delta80 +  zscore(ts_rank(i...                PASS
# 42   opt4_730_call_dis_delta40 +  zscore(ts_rank(i...                PASS
# 43   opt4_547_call_dis_delta35 +  zscore(ts_rank(i...                PASS
# 44   opt4_60_call_dis_delta20 +  zscore(ts_rank(im...                PASS
# 45   opt4_122_call_dis_delta25 +  zscore(ts_rank(i...                PASS
# 46   opt4_122_call_dis_delta20 +  zscore(ts_rank(i...                PASS
# 47   opt4_60_call_dis_delta70 +  zscore(ts_rank(im...                PASS
# 48   opt4_91_call_dis_delta80 +  zscore(ts_rank(im...                PASS
# 49   opt4_30_call_dis_delta80 +  zscore(ts_rank(im...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        FAIL       FAIL
# 1           PASS             FAIL        FAIL       FAIL
# 2           PASS             FAIL        FAIL       FAIL
# 3           PASS             FAIL        FAIL       FAIL
# 4           PASS             FAIL        FAIL       FAIL
# 5           PASS             FAIL        FAIL       FAIL
# 6           PASS             FAIL        FAIL       FAIL
# 7           PASS             FAIL        FAIL       FAIL
# 8           PASS             FAIL        FAIL       FAIL
# 9           PASS             FAIL        FAIL       FAIL
# 10          PASS             FAIL        FAIL       FAIL
# 11          PASS             FAIL        FAIL       FAIL
# 12          PASS             FAIL        FAIL       FAIL
# 13          PASS             FAIL        FAIL       FAIL
# 14          PASS             FAIL        FAIL       FAIL
# 15          PASS             FAIL        FAIL       FAIL
# 16          PASS             FAIL        FAIL       FAIL
# 17          PASS             FAIL        FAIL       FAIL
# 18          PASS             FAIL        FAIL       FAIL
# 19          PASS             FAIL        FAIL       FAIL
# 20          PASS             FAIL        FAIL       FAIL
# 21          PASS             FAIL        FAIL       FAIL
# 22          PASS             FAIL        FAIL       FAIL
# 23          PASS             FAIL        FAIL       FAIL
# 24          PASS             FAIL        FAIL       FAIL
# 25          PASS             FAIL        FAIL       FAIL
# 26          PASS             FAIL        FAIL       FAIL
# 27          PASS             FAIL        FAIL       FAIL
# 28          PASS             FAIL        FAIL       FAIL
# 29          PASS             FAIL        FAIL       FAIL
# 30          PASS             FAIL        FAIL       FAIL
# 31          PASS             FAIL        FAIL       FAIL
# 32          PASS             FAIL        FAIL       FAIL
# 33          PASS             FAIL        FAIL       FAIL
# 34          PASS             FAIL        FAIL       FAIL
# 35          PASS             FAIL        FAIL       FAIL
# 36          PASS             FAIL        FAIL       FAIL
# 37          PASS             FAIL        FAIL       FAIL
# 38          PASS             FAIL        FAIL       FAIL
# 39          PASS             FAIL        FAIL       FAIL
# 40          PASS             FAIL        FAIL       FAIL
# 41          PASS             FAIL        FAIL       FAIL
# 42          PASS             FAIL        FAIL       FAIL
# 43          PASS             FAIL        FAIL       FAIL
# 44          PASS             FAIL        FAIL       FAIL
# 45          PASS             FAIL        FAIL       FAIL
# 46          PASS             FAIL        FAIL       FAIL
# 47          PASS             FAIL        FAIL       FAIL
# 48          PASS             FAIL        FAIL       FAIL
# 49          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover matches_themes
# 0                     PASS         PASS        WARNING
# 1                     PASS         PASS        WARNING
# 2                     PASS         PASS        WARNING
# 3                     PASS         PASS        WARNING
# 4                     PASS         PASS        WARNING
# 5                     PASS         PASS        WARNING
# 6                     PASS         PASS        WARNING
# 7                     PASS         PASS        WARNING
# 8                     PASS         PASS        WARNING
# 9                     PASS         PASS        WARNING
# 10                    PASS         PASS        WARNING
# 11                    PASS         PASS        WARNING
# 12                    PASS         PASS        WARNING
# 13                    PASS         PASS        WARNING
# 14                    PASS         PASS        WARNING
# 15                    PASS         PASS        WARNING
# 16                    PASS         PASS        WARNING
# 17                    PASS         PASS        WARNING
# 18                    PASS         PASS        WARNING
# 19                    PASS         PASS        WARNING
# 20                    PASS         PASS        WARNING
# 21                    PASS         PASS        WARNING
# 22                    PASS         PASS        WARNING
# 23                    PASS         PASS        WARNING
# 24                    PASS         PASS        WARNING
# 25                    PASS         PASS        WARNING
# 26                    PASS         PASS        WARNING
# 27                    PASS         PASS        WARNING
# 28                    PASS         PASS        WARNING
# 29                    PASS         PASS        WARNING
# 30                    PASS         PASS        WARNING
# 31                    PASS         PASS        WARNING
# 32                    PASS         PASS        WARNING
# 33                    PASS         PASS        WARNING
# 34                    PASS         PASS        WARNING
# 35                    PASS         PASS        WARNING
# 36                    PASS         PASS        WARNING
# 37                    PASS         PASS        WARNING
# 38                    PASS         PASS        WARNING
# 39                    PASS         PASS        WARNING
# 40                    PASS         PASS        WARNING
# 41                    PASS         PASS        WARNING
# 42                    PASS         PASS        WARNING
# 43                    PASS         PASS        WARNING
# 44                    PASS         PASS        WARNING
# 45                    PASS         PASS        WARNING
# 46                    PASS         PASS        WARNING
# 47                    PASS         PASS        WARNING
# 48                    PASS         PASS        WARNING
# 49                    PASS         PASS        WARNING

# %%
avg_fitness2 = []
for o in final_exp_list: 
    avg_fitness_ = o['fitness'].mean()
    avg_fitness2.append(avg_fitness_)
    
avg_sharpe1 = []
for o in final_exp_list: 
    avg_sharpe = o['sharpe'].mean()
    avg_sharpe1.append(avg_sharpe)

for exp in range(len(expression_list4)):
    print(f'Average Sharpe and Fitness for {expression_list4[exp]} is: {avg_sharpe1[exp]:.2f} , {avg_fitness2[exp]:.2f}')
# Out:
# Average Sharpe and Fitness for  zscore(ts_rank(implied_volatility_call_180, 360))  is: 1.31 , 0.62
# Average Sharpe and Fitness for  zscore(ts_rank(implied_volatility_call_150, 360))  is: 1.32 , 0.63
# Average Sharpe and Fitness for  zscore(ts_rank(implied_volatility_call_270, 360))  is: 1.30 , 0.61

# %% [markdown]
# ### Since the average performance metrics from the second expression turned out to be best, we'll continue with it.

# %%
result_st = final_exp_list[1]

# %%
# Selecting alphas having best fitness among all others.
selected_expressions = result_st[result_st['fitness'] == max(result_st['fitness'])]['expression']
print("Alpha Expressions with highest fitness are: ")
selected_expressions
# Out:
# Alpha Expressions with highest fitness are:
# 0      opt4_30_call_dis_delta40 +  zscore(ts_rank(im...
# 1      opt4_152_call_dis_delta40 +  zscore(ts_rank(i...
# 2      opt4_30_call_dis_delta50 +  zscore(ts_rank(im...
# 3      opt4_273_call_dis_delta80 +  zscore(ts_rank(i...
# 4      opt4_547_call_dis_delta65 +  zscore(ts_rank(i...
# 5      opt4_182_call_dis_delta50 +  zscore(ts_rank(i...
# 6      opt4_60_call_dis_delta40 +  zscore(ts_rank(im...
# 7      opt4_152_call_dis_delta45 +  zscore(ts_rank(i...
# 8      opt4_30_call_dis_delta60 +  zscore(ts_rank(im...
# 9      opt4_91_call_dis_delta55 +  zscore(ts_rank(im...
# 10     opt4_122_call_dis_delta45 +  zscore(ts_rank(i...
# 11     opt4_91_call_dis_delta50 +  zscore(ts_rank(im...
# 12     opt4_122_call_dis_delta50 +  zscore(ts_rank(i...
# 13     opt4_122_call_dis_delta55 +  zscore(ts_rank(i...
# Name: expression, dtype: object

# %%
# Using different operators on the selected alphas to find the best performing combination.
opt_list = ['ts_rank(' , 'ts_quantile(' , 'ts_mean(', 'ts_delay(','ts_median(' , 'ts_av_diff(' , 'ts_std_dev(']

# %%
final_exp_list1 = []
for opt in opt_list:
    exp_list = [f" {opt} { x.split('+')[0] } ,30) + {x.split('+')[1]} " for x  in selected_expressions]
    alph_list = [brain.generate_alpha(x, region= "USA",truncation = 0.08, universe = "TOP3000",pasteurization = 'ON', decay = 4 ,neutralization = "SUBINDUSTRY") for x in exp_list]
    result = brain.simulate_alpha_list_multi(s, alph_list)
    result_st = hf.prettify_result(result, detailed_tests_view=False)
    final_exp_list1.append(result_st)
    display(result_st)
# Out:
# 100%|█████████████████████████████████████████████| 5/5 [02:26<00:00, 29.30s/it]
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   6006628   20000000        1186         1179    0.2909   0.0611    0.0527
# 1   5703620   20000000        1186         1181    0.2903   0.0580    0.0563
# 2   5692184   20000000        1186         1179    0.2950   0.0579    0.0578
# 3   5710173   20000000        1185         1182    0.2982   0.0581    0.0545
# 4   5715390   20000000        1186         1181    0.3087   0.0581    0.0495
# 5   5660779   20000000        1184         1183    0.3021   0.0576    0.0529
# 6   5639535   20000000        1185         1182    0.3024   0.0573    0.0505
# 7   5606310   20000000        1185         1182    0.2996   0.0570    0.0529
# 8   5601609   20000000        1183         1184    0.3002   0.0570    0.0572
# 9   5547197   20000000        1187         1179    0.3017   0.0564    0.0556
# 10  5514269   20000000        1184         1182    0.3034   0.0561    0.0484
# 11  5482905   20000000        1186         1180    0.3144   0.0557    0.0531
# 12  5390376   20000000        1184         1183    0.3002   0.0548    0.0556
# 13  5353768   20000000        1184         1183    0.2974   0.0544    0.0566
#
#       margin  fitness  sharpe alpha_id  \
# 0   0.000420     0.66    1.45  RN5Xoxb
# 1   0.000399     0.62    1.38  jnVLKrj
# 2   0.000392     0.61    1.37  mqKONnX
# 3   0.000389     0.61    1.38  onP209b
# 4   0.000376     0.60    1.38  GnQV51P
# 5   0.000381     0.59    1.36  XkNqxda
# 6   0.000379     0.59    1.36  jnVLJqO
# 7   0.000381     0.59    1.36  8OGAxpo
# 8   0.000379     0.59    1.35  QnWep2X
# 9   0.000374     0.58    1.34  Ln8eYd2
# 10  0.000370     0.57    1.33  l7gxPen
# 11  0.000355     0.56    1.34  onP2XjJ
# 12  0.000365     0.56    1.30  aNRJ9jv
# 13  0.000366     0.55    1.29  pnW0k9x
#
#                                            expression concentrated_weight  \
# 0    ts_rank(  opt4_30_call_dis_delta40  ,30) +   ...                PASS
# 1    ts_rank(  opt4_60_call_dis_delta40  ,30) +   ...                PASS
# 2    ts_rank(  opt4_30_call_dis_delta50  ,30) +   ...                PASS
# 3    ts_rank(  opt4_91_call_dis_delta50  ,30) +   ...                PASS
# 4    ts_rank(  opt4_547_call_dis_delta65  ,30) +  ...                PASS
# 5    ts_rank(  opt4_122_call_dis_delta50  ,30) +  ...                PASS
# 6    ts_rank(  opt4_122_call_dis_delta55  ,30) +  ...                PASS
# 7    ts_rank(  opt4_91_call_dis_delta55  ,30) +   ...                PASS
# 8    ts_rank(  opt4_122_call_dis_delta45  ,30) +  ...                PASS
# 9    ts_rank(  opt4_30_call_dis_delta60  ,30) +   ...                PASS
# 10   ts_rank(  opt4_182_call_dis_delta50  ,30) +  ...                PASS
# 11   ts_rank(  opt4_273_call_dis_delta80  ,30) +  ...                PASS
# 12   ts_rank(  opt4_152_call_dis_delta45  ,30) +  ...                PASS
# 13   ts_rank(  opt4_152_call_dis_delta40  ,30) +  ...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        FAIL       FAIL
# 1           PASS             FAIL        FAIL       FAIL
# 2           PASS             FAIL        FAIL       FAIL
# 3           PASS             FAIL        FAIL       FAIL
# 4           PASS             FAIL        FAIL       FAIL
# 5           PASS             FAIL        FAIL       FAIL
# 6           PASS             FAIL        FAIL       FAIL
# 7           PASS             FAIL        FAIL       FAIL
# 8           PASS             FAIL        FAIL       FAIL
# 9           PASS             FAIL        FAIL       FAIL
# 10          PASS             FAIL        FAIL       FAIL
# 11          PASS             FAIL        FAIL       FAIL
# 12          PASS             FAIL        FAIL       FAIL
# 13          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover matches_themes
# 0                     PASS         PASS        WARNING
# 1                     PASS         PASS        WARNING
# 2                     PASS         PASS        WARNING
# 3                     PASS         PASS        WARNING
# 4                     PASS         PASS        WARNING
# 5                     PASS         PASS        WARNING
# 6                     PASS         PASS        WARNING
# 7                     PASS         PASS        WARNING
# 8                     PASS         PASS        WARNING
# 9                     PASS         PASS        WARNING
# 10                    FAIL         PASS        WARNING
# 11                    PASS         PASS        WARNING
# 12                    PASS         PASS        WARNING
# 13                    PASS         PASS        WARNING
# 100%|█████████████████████████████████████████████| 5/5 [02:36<00:00, 31.36s/it]
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   5821957   20000000        1186         1179    0.3931   0.0592    0.0414
# 1   5133505   20000000        1188         1178    0.3874   0.0522    0.0516
# 2   5193003   20000000        1182         1184    0.4042   0.0528    0.0438
# 3   5301862   20000000        1183         1183    0.4490   0.0539    0.0357
# 4   5049133   20000000        1185         1179    0.4013   0.0513    0.0534
# 5   5104417   20000000        1182         1184    0.4147   0.0519    0.0459
# 6   5079481   20000000        1183         1183    0.4184   0.0516    0.0440
# 7   4978630   20000000        1183         1183    0.4094   0.0506    0.0423
# 8   4937263   20000000        1182         1184    0.4102   0.0502    0.0515
# 9   4864373   20000000        1185         1179    0.4207   0.0495    0.0479
# 10  4814744   20000000        1181         1184    0.4661   0.0490    0.0435
# 11  4702281   20000000        1186         1180    0.4182   0.0478    0.0418
# 12  4484969   20000000        1185         1181    0.4091   0.0456    0.0488
# 13  4370493   20000000        1185         1181    0.4051   0.0444    0.0500
#
#       margin  fitness  sharpe alpha_id  \
# 0   0.000301     0.61    1.58  NnKMlY8
# 1   0.000269     0.52    1.43  2vGEVO8
# 2   0.000261     0.51    1.41  kn8Rp3L
# 3   0.000240     0.50    1.43  1oGvArJ
# 4   0.000256     0.49    1.36  6RGxL5K
# 5   0.000250     0.49    1.38  qn5bJQ1
# 6   0.000247     0.48    1.37  KnVeMWN
# 7   0.000247     0.48    1.36  dn9qJOj
# 8   0.000245     0.47    1.34  jnVLkZZ
# 9   0.000235     0.45    1.31  dn9qJOg
# 10  0.000210     0.43    1.33  jnVLk55
# 11  0.000229     0.43    1.28  onP20x2
# 12  0.000223     0.41    1.23  l7gxPoN
# 13  0.000219     0.40    1.20  On6eXlb
#
#                                            expression concentrated_weight  \
# 0    ts_quantile(  opt4_30_call_dis_delta40  ,30) ...                PASS
# 1    ts_quantile(  opt4_60_call_dis_delta40  ,30) ...                PASS
# 2    ts_quantile(  opt4_91_call_dis_delta50  ,30) ...                PASS
# 3    ts_quantile(  opt4_547_call_dis_delta65  ,30)...                PASS
# 4    ts_quantile(  opt4_30_call_dis_delta50  ,30) ...                PASS
# 5    ts_quantile(  opt4_122_call_dis_delta50  ,30)...                PASS
# 6    ts_quantile(  opt4_122_call_dis_delta55  ,30)...                PASS
# 7    ts_quantile(  opt4_91_call_dis_delta55  ,30) ...                PASS
# 8    ts_quantile(  opt4_122_call_dis_delta45  ,30)...                PASS
# 9    ts_quantile(  opt4_30_call_dis_delta60  ,30) ...                PASS
# 10   ts_quantile(  opt4_273_call_dis_delta80  ,30)...                PASS
# 11   ts_quantile(  opt4_182_call_dis_delta50  ,30)...                PASS
# 12   ts_quantile(  opt4_152_call_dis_delta45  ,30)...                PASS
# 13   ts_quantile(  opt4_152_call_dis_delta40  ,30)...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        FAIL       PASS
# 1           PASS             FAIL        FAIL       FAIL
# 2           PASS             FAIL        FAIL       FAIL
# 3           PASS             FAIL        FAIL       FAIL
# 4           PASS             FAIL        FAIL       FAIL
# 5           PASS             FAIL        FAIL       FAIL
# 6           PASS             FAIL        FAIL       FAIL
# 7           PASS             FAIL        FAIL       FAIL
# 8           PASS             FAIL        FAIL       FAIL
# 9           PASS             FAIL        FAIL       FAIL
# 10          PASS             FAIL        FAIL       FAIL
# 11          PASS             FAIL        FAIL       FAIL
# 12          PASS             FAIL        FAIL       FAIL
# 13          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover matches_themes
# 0                     PASS         PASS        WARNING
# 1                     PASS         PASS        WARNING
# 2                     FAIL         PASS        WARNING
# 3                     PASS         PASS        WARNING
# 4                     PASS         PASS        WARNING
# 5                     FAIL         PASS        WARNING
# 6                     PASS         PASS        WARNING
# 7                     FAIL         PASS        WARNING
# 8                     PASS         PASS        WARNING
# 9                     PASS         PASS        WARNING
# 10                    PASS         PASS        WARNING
# 11                    FAIL         PASS        WARNING
# 12                    FAIL         PASS        WARNING
# 13                    PASS         PASS        WARNING
# 100%|█████████████████████████████████████████████| 5/5 [02:10<00:00, 26.14s/it]
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   5727008   20000000        1190         1180    0.2540   0.0582    0.0570
# 1   5718790   20000000        1192         1178    0.2539   0.0581    0.0571
# 2   5723072   20000000        1191         1179    0.2540   0.0582    0.0572
# 3   5693903   20000000        1191         1179    0.2540   0.0579    0.0569
# 4   5746296   20000000        1191         1180    0.2539   0.0584    0.0573
# 5   5741064   20000000        1191         1179    0.2539   0.0584    0.0574
# 6   5728757   20000000        1191         1180    0.2539   0.0582    0.0574
# 7   5746581   20000000        1190         1180    0.2539   0.0584    0.0575
# 8   5748093   20000000        1190         1180    0.2540   0.0584    0.0574
# 9   5709014   20000000        1189         1181    0.2539   0.0580    0.0589
# 10  5735171   20000000        1190         1180    0.2539   0.0583    0.0576
# 11  5694773   20000000        1191         1179    0.2538   0.0579    0.0581
# 12  5730662   20000000        1189         1181    0.2538   0.0583    0.0588
# 13  5732673   20000000        1190         1180    0.2539   0.0583    0.0573
#
#       margin  fitness  sharpe alpha_id  \
# 0   0.000458     0.64    1.33  bNxpmZl
# 1   0.000458     0.64    1.34  7xGO5W2
# 2   0.000458     0.64    1.33  kn8Rwdg
# 3   0.000456     0.64    1.33  xelMLkw
# 4   0.000460     0.64    1.33  KnVeoPl
# 5   0.000460     0.64    1.33  kn8RwqL
# 6   0.000459     0.64    1.33  8OGA0Qz
# 7   0.000460     0.64    1.33  Ln8evnM
# 8   0.000460     0.64    1.33  w5N6d51
# 9   0.000457     0.63    1.32  AnL6pZd
# 10  0.000459     0.63    1.32  MbgwEP9
# 11  0.000456     0.63    1.32  Ln8eva6
# 12  0.000459     0.63    1.31  onP2bl5
# 13  0.000459     0.63    1.32  dn9qMX2
#
#                                            expression concentrated_weight  \
# 0    ts_mean(  opt4_30_call_dis_delta50  ,30) +   ...                PASS
# 1    ts_mean(  opt4_547_call_dis_delta65  ,30) +  ...                PASS
# 2    ts_mean(  opt4_182_call_dis_delta50  ,30) +  ...                PASS
# 3    ts_mean(  opt4_30_call_dis_delta60  ,30) +   ...                PASS
# 4    ts_mean(  opt4_122_call_dis_delta50  ,30) +  ...                PASS
# 5    ts_mean(  opt4_122_call_dis_delta55  ,30) +  ...                PASS
# 6    ts_mean(  opt4_91_call_dis_delta55  ,30) +   ...                PASS
# 7    ts_mean(  opt4_122_call_dis_delta45  ,30) +  ...                PASS
# 8    ts_mean(  opt4_91_call_dis_delta50  ,30) +   ...                PASS
# 9    ts_mean(  opt4_30_call_dis_delta40  ,30) +   ...                PASS
# 10   ts_mean(  opt4_152_call_dis_delta40  ,30) +  ...                PASS
# 11   ts_mean(  opt4_273_call_dis_delta80  ,30) +  ...                PASS
# 12   ts_mean(  opt4_60_call_dis_delta40  ,30) +   ...                PASS
# 13   ts_mean(  opt4_152_call_dis_delta45  ,30) +  ...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        FAIL       FAIL
# 1           PASS             FAIL        FAIL       FAIL
# 2           PASS             FAIL        FAIL       FAIL
# 3           PASS             FAIL        FAIL       FAIL
# 4           PASS             FAIL        FAIL       FAIL
# 5           PASS             FAIL        FAIL       FAIL
# 6           PASS             FAIL        FAIL       FAIL
# 7           PASS             FAIL        FAIL       FAIL
# 8           PASS             FAIL        FAIL       FAIL
# 9           PASS             FAIL        FAIL       FAIL
# 10          PASS             FAIL        FAIL       FAIL
# 11          PASS             FAIL        FAIL       FAIL
# 12          PASS             FAIL        FAIL       FAIL
# 13          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover matches_themes
# 0                     PASS         PASS        WARNING
# 1                     PASS         PASS        WARNING
# 2                     PASS         PASS        WARNING
# 3                     PASS         PASS        WARNING
# 4                     PASS         PASS        WARNING
# 5                     PASS         PASS        WARNING
# 6                     PASS         PASS        WARNING
# 7                     PASS         PASS        WARNING
# 8                     PASS         PASS        WARNING
# 9                     PASS         PASS        WARNING
# 10                    PASS         PASS        WARNING
# 11                    PASS         PASS        WARNING
# 12                    PASS         PASS        WARNING
# 13                    PASS         PASS        WARNING
# 100%|█████████████████████████████████████████████| 5/5 [01:56<00:00, 23.29s/it]
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   5719235   20000000        1177         1168    0.2533   0.0581    0.0569
# 1   5743515   20000000        1176         1169    0.2534   0.0584    0.0566
# 2   5742471   20000000        1176         1168    0.2535   0.0584    0.0567
# 3   5729727   20000000        1175         1170    0.2543   0.0583    0.0578
# 4   5732690   20000000        1176         1168    0.2532   0.0583    0.0568
# 5   5658718   20000000        1176         1168    0.2556   0.0575    0.0556
# 6   5677263   20000000        1178         1167    0.2534   0.0577    0.0578
# 7   5687494   20000000        1177         1168    0.2533   0.0578    0.0570
# 8   5722169   20000000        1176         1169    0.2533   0.0582    0.0571
# 9   5726473   20000000        1175         1168    0.2556   0.0582    0.0558
# 10  5702754   20000000        1177         1168    0.2533   0.0580    0.0570
# 11  5688202   20000000        1177         1168    0.2534   0.0578    0.0568
# 12  5606378   20000000        1177         1167    0.2543   0.0570    0.0589
# 13  5635508   20000000        1174         1169    0.2562   0.0573    0.0573
#
#       margin  fitness  sharpe alpha_id  \
# 0   0.000459     0.64    1.33  ZjXZ8O3
# 1   0.000461     0.64    1.33  RN5XgYb
# 2   0.000461     0.64    1.33  z5AaVjO
# 3   0.000458     0.63    1.32  8OGAwrX
# 4   0.000460     0.63    1.32  8OGAwmq
# 5   0.000450     0.63    1.32  5LGRX9X
# 6   0.000456     0.63    1.33  rb0kx13
# 7   0.000457     0.63    1.32  RN5XOGg
# 8   0.000459     0.63    1.32  Jn3lA6n
# 9   0.000456     0.63    1.33  2vGEY15
# 10  0.000458     0.63    1.32  GnQV2ZO
# 11  0.000456     0.63    1.32  l7gxmzO
# 12  0.000448     0.62    1.31  Eqm3dZP
# 13  0.000447     0.61    1.30  7xGOpkv
#
#                                            expression concentrated_weight  \
# 0    ts_delay(  opt4_122_call_dis_delta50  ,30) + ...                PASS
# 1    ts_delay(  opt4_122_call_dis_delta45  ,30) + ...                PASS
# 2    ts_delay(  opt4_91_call_dis_delta50  ,30) +  ...                PASS
# 3    ts_delay(  opt4_60_call_dis_delta40  ,30) +  ...                PASS
# 4    ts_delay(  opt4_152_call_dis_delta45  ,30) + ...                PASS
# 5    ts_delay(  opt4_30_call_dis_delta60  ,30) +  ...                PASS
# 6    ts_delay(  opt4_547_call_dis_delta65  ,30) + ...                PASS
# 7    ts_delay(  opt4_182_call_dis_delta50  ,30) + ...                PASS
# 8    ts_delay(  opt4_152_call_dis_delta40  ,30) + ...                PASS
# 9    ts_delay(  opt4_30_call_dis_delta50  ,30) +  ...                PASS
# 10   ts_delay(  opt4_122_call_dis_delta55  ,30) + ...                PASS
# 11   ts_delay(  opt4_91_call_dis_delta55  ,30) +  ...                PASS
# 12   ts_delay(  opt4_273_call_dis_delta80  ,30) + ...                PASS
# 13   ts_delay(  opt4_30_call_dis_delta40  ,30) +  ...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        FAIL       FAIL
# 1           PASS             FAIL        FAIL       FAIL
# 2           PASS             FAIL        FAIL       FAIL
# 3           PASS             FAIL        FAIL       FAIL
# 4           PASS             FAIL        FAIL       FAIL
# 5           PASS             FAIL        FAIL       FAIL
# 6           PASS             FAIL        FAIL       FAIL
# 7           PASS             FAIL        FAIL       FAIL
# 8           PASS             FAIL        FAIL       FAIL
# 9           PASS             FAIL        FAIL       FAIL
# 10          PASS             FAIL        FAIL       FAIL
# 11          PASS             FAIL        FAIL       FAIL
# 12          PASS             FAIL        FAIL       FAIL
# 13          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover matches_themes
# 0                     PASS         PASS        WARNING
# 1                     PASS         PASS        WARNING
# 2                     PASS         PASS        WARNING
# 3                     PASS         PASS        WARNING
# 4                     PASS         PASS        WARNING
# 5                     PASS         PASS        WARNING
# 6                     PASS         PASS        WARNING
# 7                     PASS         PASS        WARNING
# 8                     PASS         PASS        WARNING
# 9                     PASS         PASS        WARNING
# 10                    PASS         PASS        WARNING
# 11                    PASS         PASS        WARNING
# 12                    PASS         PASS        WARNING
# 13                    PASS         PASS        WARNING
# 100%|█████████████████████████████████████████████| 5/5 [02:37<00:00, 31.40s/it]
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   5707318   20000000        1192         1178    0.2540   0.0580    0.0568
# 1   5707132   20000000        1191         1179    0.2540   0.0580    0.0571
# 2   5704106   20000000        1191         1179    0.2540   0.0580    0.0561
# 3   5712042   20000000        1191         1180    0.2539   0.0581    0.0570
# 4   5701132   20000000        1191         1179    0.2539   0.0580    0.0571
# 5   5728156   20000000        1191         1180    0.2539   0.0582    0.0569
# 6   5716813   20000000        1191         1179    0.2540   0.0581    0.0570
# 7   5718299   20000000        1191         1179    0.2539   0.0581    0.0570
# 8   5712453   20000000        1191         1179    0.2539   0.0581    0.0572
# 9   5678824   20000000        1192         1178    0.2538   0.0577    0.0572
# 10  5696047   20000000        1190         1180    0.2540   0.0579    0.0574
# 11  5718103   20000000        1190         1180    0.2539   0.0581    0.0571
# 12  5715396   20000000        1190         1181    0.2539   0.0581    0.0577
# 13  5676207   20000000        1191         1179    0.2540   0.0577    0.0562
#
#       margin  fitness  sharpe alpha_id  \
# 0   0.000457     0.64    1.34  2vGEY28
# 1   0.000457     0.64    1.33  GnQVR9Z
# 2   0.000457     0.64    1.33  l7gxm9N
# 3   0.000457     0.64    1.33  AnL6A2d
# 4   0.000456     0.64    1.33  dn9qNE2
# 5   0.000459     0.64    1.33  5LGRPR1
# 6   0.000458     0.64    1.33  3EGd8d0
# 7   0.000458     0.64    1.33  nn60EQE
# 8   0.000457     0.64    1.33  onP2dZ2
# 9   0.000455     0.63    1.33  qn5bRV1
# 10  0.000456     0.63    1.32  pnW0LZb
# 11  0.000458     0.63    1.32  7xGOplb
# 12  0.000458     0.63    1.32  bNxpeWr
# 13  0.000454     0.63    1.33  mqKOExW
#
#                                            expression concentrated_weight  \
# 0    ts_median(  opt4_547_call_dis_delta65  ,30) +...                PASS
# 1    ts_median(  opt4_182_call_dis_delta50  ,30) +...                PASS
# 2    ts_median(  opt4_30_call_dis_delta50  ,30) + ...                PASS
# 3    ts_median(  opt4_152_call_dis_delta45  ,30) +...                PASS
# 4    ts_median(  opt4_91_call_dis_delta55  ,30) + ...                PASS
# 5    ts_median(  opt4_122_call_dis_delta45  ,30) +...                PASS
# 6    ts_median(  opt4_91_call_dis_delta50  ,30) + ...                PASS
# 7    ts_median(  opt4_122_call_dis_delta50  ,30) +...                PASS
# 8    ts_median(  opt4_122_call_dis_delta55  ,30) +...                PASS
# 9    ts_median(  opt4_273_call_dis_delta80  ,30) +...                PASS
# 10   ts_median(  opt4_30_call_dis_delta40  ,30) + ...                PASS
# 11   ts_median(  opt4_152_call_dis_delta40  ,30) +...                PASS
# 12   ts_median(  opt4_60_call_dis_delta40  ,30) + ...                PASS
# 13   ts_median(  opt4_30_call_dis_delta60  ,30) + ...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        FAIL       FAIL
# 1           PASS             FAIL        FAIL       FAIL
# 2           PASS             FAIL        FAIL       FAIL
# 3           PASS             FAIL        FAIL       FAIL
# 4           PASS             FAIL        FAIL       FAIL
# 5           PASS             FAIL        FAIL       FAIL
# 6           PASS             FAIL        FAIL       FAIL
# 7           PASS             FAIL        FAIL       FAIL
# 8           PASS             FAIL        FAIL       FAIL
# 9           PASS             FAIL        FAIL       FAIL
# 10          PASS             FAIL        FAIL       FAIL
# 11          PASS             FAIL        FAIL       FAIL
# 12          PASS             FAIL        FAIL       FAIL
# 13          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover matches_themes
# 0                     PASS         PASS        WARNING
# 1                     PASS         PASS        WARNING
# 2                     PASS         PASS        WARNING
# 3                     PASS         PASS        WARNING
# 4                     PASS         PASS        WARNING
# 5                     PASS         PASS        WARNING
# 6                     PASS         PASS        WARNING
# 7                     PASS         PASS        WARNING
# 8                     PASS         PASS        WARNING
# 9                     PASS         PASS        WARNING
# 10                    PASS         PASS        WARNING
# 11                    PASS         PASS        WARNING
# 12                    PASS         PASS        WARNING
# 13                    PASS         PASS        WARNING
# 100%|█████████████████████████████████████████████| 5/5 [02:01<00:00, 24.30s/it]
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   5706187   20000000        1189         1177    0.2579   0.0580    0.0564
# 1   5693043   20000000        1189         1176    0.2575   0.0579    0.0572
# 2   5616425   20000000        1190         1177    0.2554   0.0571    0.0578
# 3   5609389   20000000        1190         1177    0.2562   0.0570    0.0576
# 4   5596364   20000000        1190         1177    0.2554   0.0569    0.0577
# 5   5646032   20000000        1189         1176    0.2579   0.0574    0.0566
# 6   5630410   20000000        1190         1176    0.2580   0.0572    0.0556
# 7   5592499   20000000        1190         1176    0.2554   0.0569    0.0561
# 8   5604076   20000000        1190         1177    0.2555   0.0570    0.0564
# 9   5627125   20000000        1190         1177    0.2557   0.0572    0.0567
# 10  5631454   20000000        1190         1177    0.2557   0.0573    0.0572
# 11  5594945   20000000        1190         1177    0.2556   0.0569    0.0570
# 12  5582229   20000000        1190         1177    0.2556   0.0568    0.0568
# 13  5577888   20000000        1190         1177    0.2555   0.0567    0.0576
#
#       margin  fitness  sharpe alpha_id  \
# 0   0.000450     0.64    1.36  YNlZRJR
# 1   0.000450     0.64    1.35  1oGvrPX
# 2   0.000447     0.63    1.34  3EGd8JN
# 3   0.000445     0.63    1.33  nn6w10z
# 4   0.000445     0.63    1.33  MbgwJNL
# 5   0.000445     0.63    1.34  2vGP1EJ
# 6   0.000444     0.63    1.34  pnW093X
# 7   0.000445     0.63    1.33  PnPekmw
# 8   0.000446     0.63    1.33  ZjXZOvZ
# 9   0.000448     0.63    1.34  AnLqR6l
# 10  0.000448     0.63    1.34  On6K1eR
# 11  0.000445     0.63    1.33  RN5XGPz
# 12  0.000444     0.63    1.33  0AGo1av
# 13  0.000444     0.62    1.32  8OGgmAW
#
#                                            expression concentrated_weight  \
# 0    ts_av_diff(  opt4_30_call_dis_delta40  ,30) +...                PASS
# 1    ts_av_diff(  opt4_30_call_dis_delta50  ,30) +...                PASS
# 2    ts_av_diff(  opt4_152_call_dis_delta40  ,30) ...                PASS
# 3    ts_av_diff(  opt4_60_call_dis_delta40  ,30) +...                PASS
# 4    ts_av_diff(  opt4_152_call_dis_delta45  ,30) ...                PASS
# 5    ts_av_diff(  opt4_30_call_dis_delta60  ,30) +...                PASS
# 6    ts_av_diff(  opt4_273_call_dis_delta80  ,30) ...                PASS
# 7    ts_av_diff(  opt4_547_call_dis_delta65  ,30) ...                PASS
# 8    ts_av_diff(  opt4_182_call_dis_delta50  ,30) ...                PASS
# 9    ts_av_diff(  opt4_91_call_dis_delta55  ,30) +...                PASS
# 10   ts_av_diff(  opt4_91_call_dis_delta50  ,30) +...                PASS
# 11   ts_av_diff(  opt4_122_call_dis_delta50  ,30) ...                PASS
# 12   ts_av_diff(  opt4_122_call_dis_delta55  ,30) ...                PASS
# 13   ts_av_diff(  opt4_122_call_dis_delta45  ,30) ...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        FAIL       FAIL
# 1           PASS             FAIL        FAIL       FAIL
# 2           PASS             FAIL        FAIL       FAIL
# 3           PASS             FAIL        FAIL       FAIL
# 4           PASS             FAIL        FAIL       FAIL
# 5           PASS             FAIL        FAIL       FAIL
# 6           PASS             FAIL        FAIL       FAIL
# 7           PASS             FAIL        FAIL       FAIL
# 8           PASS             FAIL        FAIL       FAIL
# 9           PASS             FAIL        FAIL       FAIL
# 10          PASS             FAIL        FAIL       FAIL
# 11          PASS             FAIL        FAIL       FAIL
# 12          PASS             FAIL        FAIL       FAIL
# 13          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover matches_themes
# 0                     PASS         PASS        WARNING
# 1                     PASS         PASS        WARNING
# 2                     PASS         PASS        WARNING
# 3                     PASS         PASS        WARNING
# 4                     PASS         PASS        WARNING
# 5                     PASS         PASS        WARNING
# 6                     PASS         PASS        WARNING
# 7                     PASS         PASS        WARNING
# 8                     PASS         PASS        WARNING
# 9                     PASS         PASS        WARNING
# 10                    PASS         PASS        WARNING
# 11                    PASS         PASS        WARNING
# 12                    PASS         PASS        WARNING
# 13                    PASS         PASS        WARNING
# 100%|█████████████████████████████████████████████| 5/5 [02:37<00:00, 31.47s/it]
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   5629859   20000000        1191         1179    0.2542   0.0572    0.0573
# 1   5656169   20000000        1191         1179    0.2542   0.0575    0.0572
# 2   5666015   20000000        1191         1179    0.2542   0.0576    0.0576
# 3   5677455   20000000        1190         1179    0.2542   0.0577    0.0578
# 4   5678389   20000000        1189         1180    0.2542   0.0577    0.0582
# 5   5674979   20000000        1191         1179    0.2542   0.0577    0.0575
# 6   5667407   20000000        1191         1179    0.2542   0.0576    0.0575
# 7   5662144   20000000        1190         1179    0.2542   0.0576    0.0575
# 8   5692914   20000000        1190         1179    0.2542   0.0579    0.0579
# 9   5626148   20000000        1191         1179    0.2541   0.0572    0.0589
# 10  5655441   20000000        1190         1180    0.2541   0.0575    0.0600
# 11  5675389   20000000        1189         1180    0.2541   0.0577    0.0599
# 12  5631996   20000000        1190         1179    0.2542   0.0573    0.0579
# 13  5666429   20000000        1190         1179    0.2542   0.0576    0.0580
#
#       margin  fitness  sharpe alpha_id  \
# 0   0.000450     0.63    1.32  KnVxKz1
# 1   0.000452     0.63    1.32  On6K1zR
# 2   0.000453     0.63    1.32  kn8exOk
# 3   0.000454     0.63    1.32  Ln8OLXn
# 4   0.000454     0.63    1.32  WNYKE0j
# 5   0.000454     0.63    1.32  nn6wpwq
# 6   0.000453     0.63    1.32  rb0QK6E
# 7   0.000453     0.63    1.32  Eqmo5aR
# 8   0.000455     0.63    1.32  On6K0vd
# 9   0.000450     0.62    1.31  On6K1VR
# 10  0.000453     0.62    1.30  mqKeLz2
# 11  0.000454     0.62    1.31  jnVN5x9
# 12  0.000451     0.62    1.31  Ln8OLba
# 13  0.000453     0.62    1.31  PnPj0eE
#
#                                            expression concentrated_weight  \
# 0    ts_std_dev(  opt4_547_call_dis_delta65  ,30) ...                PASS
# 1    ts_std_dev(  opt4_182_call_dis_delta50  ,30) ...                PASS
# 2    ts_std_dev(  opt4_152_call_dis_delta45  ,30) ...                PASS
# 3    ts_std_dev(  opt4_30_call_dis_delta60  ,30) +...                PASS
# 4    ts_std_dev(  opt4_30_call_dis_delta50  ,30) +...                PASS
# 5    ts_std_dev(  opt4_122_call_dis_delta50  ,30) ...                PASS
# 6    ts_std_dev(  opt4_122_call_dis_delta55  ,30) ...                PASS
# 7    ts_std_dev(  opt4_91_call_dis_delta55  ,30) +...                PASS
# 8    ts_std_dev(  opt4_91_call_dis_delta50  ,30) +...                PASS
# 9    ts_std_dev(  opt4_273_call_dis_delta80  ,30) ...                PASS
# 10   ts_std_dev(  opt4_60_call_dis_delta40  ,30) +...                PASS
# 11   ts_std_dev(  opt4_30_call_dis_delta40  ,30) +...                PASS
# 12   ts_std_dev(  opt4_152_call_dis_delta40  ,30) ...                PASS
# 13   ts_std_dev(  opt4_122_call_dis_delta45  ,30) ...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        FAIL       FAIL
# 1           PASS             FAIL        FAIL       FAIL
# 2           PASS             FAIL        FAIL       FAIL
# 3           PASS             FAIL        FAIL       FAIL
# 4           PASS             FAIL        FAIL       FAIL
# 5           PASS             FAIL        FAIL       FAIL
# 6           PASS             FAIL        FAIL       FAIL
# 7           PASS             FAIL        FAIL       FAIL
# 8           PASS             FAIL        FAIL       FAIL
# 9           PASS             FAIL        FAIL       FAIL
# 10          PASS             FAIL        FAIL       FAIL
# 11          PASS             FAIL        FAIL       FAIL
# 12          PASS             FAIL        FAIL       FAIL
# 13          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover matches_themes
# 0                     PASS         PASS        WARNING
# 1                     PASS         PASS        WARNING
# 2                     PASS         PASS        WARNING
# 3                     PASS         PASS        WARNING
# 4                     PASS         PASS        WARNING
# 5                     PASS         PASS        WARNING
# 6                     PASS         PASS        WARNING
# 7                     PASS         PASS        WARNING
# 8                     PASS         PASS        WARNING
# 9                     PASS         PASS        WARNING
# 10                    PASS         PASS        WARNING
# 11                    PASS         PASS        WARNING
# 12                    PASS         PASS        WARNING
# 13                    PASS         PASS        WARNING

# %%
avg_sharpe3 = []
for o in final_exp_list1: 
    avg_sharpe = o['sharpe'].mean()
    avg_sharpe3.append(avg_sharpe)

for opt in range(len(opt_list)):
    print(f'Average Sharpe for {opt_list[opt]}) is: {avg_sharpe3[opt]:.2f}')
# Out:
# Average Sharpe for ts_rank() is: 1.36
# Average Sharpe for ts_quantile() is: 1.36
# Average Sharpe for ts_mean() is: 1.33
# Average Sharpe for ts_delay() is: 1.32
# Average Sharpe for ts_median() is: 1.33
# Average Sharpe for ts_av_diff() is: 1.34
# Average Sharpe for ts_std_dev() is: 1.32

# %%
# Using Fitness as the tie-breaker

avg_fitness3 = []
for o in final_exp_list1: 
    avg_fitness_ = o['fitness'].mean()
    avg_fitness3.append(avg_fitness_)
    
for opt in range(2):    
    print(f"Average Fitness for {opt_list[opt]}) is: {avg_fitness3[opt]:.2f}")
# Out:
# Average Fitness for ts_rank() is: 0.59
# Average Fitness for ts_quantile() is: 0.48

# %% [markdown]
# ### Clearly ts_rank() demonstrates the highest efficacy, so we take this particular expression to further analyse.

# %%
selected_alpha = 'zscore(ts_rank(implied_volatility_call_150, 360)) + ts_rank(opt4_30_call_dis_delta40, 30)'

# %%
alpha_temp =[ brain.generate_alpha(selected_alpha , region= "USA",truncation = 0.08, universe = "TOP3000",pasteurization = 'ON', decay = 4 ,neutralization = "SUBINDUSTRY") ]
result_temp = brain.simulate_alpha_list_multi(s, alpha_temp)
results_temp = hf.prettify_result(result_temp, detailed_tests_view=False)
# Out:
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 1/1 [00:38<00:00, 38.14s/it]

# %%
display(results_temp)
# Out:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  6006628   20000000        1186         1179    0.2909   0.0611    0.0527
#
#     margin  fitness  sharpe alpha_id  \
# 0  0.00042     0.66    1.45  qn7a1EO
#
#                                           expression concentrated_weight  \
# 0  zscore(ts_rank(implied_volatility_call_150, 36...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING

# %% [markdown]
# ### With turnover currently at 29%, we aim to reduce it by employing turnover-reducing operators. It's crucial to note that the alpha itself generates the signal.

# %%
turnover_red_opt_list = ['trade_when(rank(implied_volatility_call_150)>0.1,  ' , 'trade_when(rank(implied_volatility_call_150)>0.15,  ', 'trade_when(rank(implied_volatility_call_150)>0.2,  ' , 'trade_when(rank(implied_volatility_call_150)>0.25,  ', 'trade_when(rank(implied_volatility_call_150)>0.3,  ', 'trade_when(rank(implied_volatility_call_150)>0.35,  ',  'if_else(rank(implied_volatility_call_150)>0.1, ' , 'if_else(rank(implied_volatility_call_150)>0.15, ' , 'if_else(rank(implied_volatility_call_150)>0.2, ' , 'if_else(rank(implied_volatility_call_150)>0.25, ', 'if_else(rank(implied_volatility_call_150)>0.3, ','if_else(rank(implied_volatility_call_150)>0.35, ']

exp_list_after = [f" {opt} { selected_alpha } , -1) " for opt in turnover_red_opt_list]
alph_list_after = [brain.generate_alpha(x, region= "USA",truncation = 0.08, universe = "TOP3000",pasteurization = 'ON', decay = 4 ,neutralization = "SUBINDUSTRY") for x in exp_list_after]
result_after = brain.simulate_alpha_list_multi(s, alph_list_after)
result_st_after = hf.prettify_result(result_after, detailed_tests_view=False)
display(result_st_after)
# Out:
# 100%|█████████████████████████████████████████████| 4/4 [02:04<00:00, 31.00s/it]
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   4934792   20000000        1298         1260    0.2048   0.0502    0.0380
# 1   4679890   20000000        1293         1244    0.1965   0.0476    0.0338
# 2   4425527   20000000        1284         1226    0.1885   0.0450    0.0522
# 3   4279552   20000000        1253         1182    0.1723   0.0435    0.0802
# 4   4310327   20000000        1269         1202    0.1813   0.0438    0.0631
# 5   6355673   20000000        1161         1208    0.2792   0.0646    0.0662
# 6   4074802   20000000        1230         1154    0.1646   0.0414    0.0990
# 7   6450971   20000000        1139         1227    0.2713   0.0656    0.0780
# 8   6550492   20000000        1113         1248    0.2646   0.0666    0.0879
# 9   6619412   20000000        1081         1271    0.2574   0.0673    0.1041
# 10  6765957   20000000        1046         1294    0.2506   0.0688    0.1197
# 11  6825816   20000000        1005         1319    0.2440   0.0694    0.1271
#
#       margin  fitness  sharpe alpha_id  \
# 0   0.000490     0.73    1.47  RN50wkd
# 1   0.000484     0.71    1.44  3EGgvnX
# 2   0.000477     0.68    1.40  5LGNdq5
# 3   0.000505     0.68    1.35  pnWQdKb
# 4   0.000483     0.67    1.37  mqKed65
# 5   0.000463     0.65    1.35  6RGgLYG
# 6   0.000503     0.64    1.28  LnKvj5v
# 7   0.000484     0.62    1.26  dn9er3j
# 8   0.000503     0.59    1.18  On6KXMJ
# 9   0.000523     0.57    1.12  GnQEXYQ
# 10  0.000549     0.57    1.08  bNx763N
# 11  0.000569     0.55    1.04  0AGnYWq
#
#                                            expression concentrated_weight  \
# 0    trade_when(rank(implied_volatility_call_150)>...                PASS
# 1    trade_when(rank(implied_volatility_call_150)>...                PASS
# 2    trade_when(rank(implied_volatility_call_150)>...                PASS
# 3    trade_when(rank(implied_volatility_call_150)>...                PASS
# 4    trade_when(rank(implied_volatility_call_150)>...                PASS
# 5    if_else(rank(implied_volatility_call_150)>0.1...                PASS
# 6   trade_when(rank(implied_volatility_call_150)>0...                PASS
# 7    if_else(rank(implied_volatility_call_150)>0.1...                PASS
# 8    if_else(rank(implied_volatility_call_150)>0.2...                PASS
# 9    if_else(rank(implied_volatility_call_150)>0.2...                PASS
# 10   if_else(rank(implied_volatility_call_150)>0.3...                PASS
# 11   if_else(rank(implied_volatility_call_150)>0.3...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        FAIL       FAIL
# 1           PASS             FAIL        FAIL       FAIL
# 2           PASS             FAIL        FAIL       FAIL
# 3           PASS             FAIL        FAIL       FAIL
# 4           PASS             FAIL        FAIL       FAIL
# 5           PASS             FAIL        FAIL       FAIL
# 6           PASS             FAIL        FAIL       FAIL
# 7           PASS             FAIL        FAIL       FAIL
# 8           PASS             FAIL        FAIL       FAIL
# 9           PASS             FAIL        FAIL       FAIL
# 10          PASS             FAIL        FAIL       FAIL
# 11          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover matches_themes
# 0                     PASS         PASS        WARNING
# 1                     PASS         PASS        WARNING
# 2                     FAIL         PASS        WARNING
# 3                     PASS         PASS        WARNING
# 4                     FAIL         PASS        WARNING
# 5                     PASS         PASS        WARNING
# 6                     PASS         PASS        WARNING
# 7                     PASS         PASS        WARNING
# 8                     PASS         PASS        WARNING
# 9                     PASS         PASS        WARNING
# 10                    PASS         PASS        WARNING
# 11                    PASS         PASS        WARNING

# %% [markdown]
# ### Selecting the lowest turnover Alpha Expression

# %%
result_st_after.sort_values(by='turnover', ascending = True, inplace = False)
result_st_after
# Out:
#         pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0   4934792   20000000        1298         1260    0.2048   0.0502    0.0380
# 1   4679890   20000000        1293         1244    0.1965   0.0476    0.0338
# 2   4425527   20000000        1284         1226    0.1885   0.0450    0.0522
# 3   4279552   20000000        1253         1182    0.1723   0.0435    0.0802
# 4   4310327   20000000        1269         1202    0.1813   0.0438    0.0631
# 5   6355673   20000000        1161         1208    0.2792   0.0646    0.0662
# 6   4074802   20000000        1230         1154    0.1646   0.0414    0.0990
# 7   6450971   20000000        1139         1227    0.2713   0.0656    0.0780
# 8   6550492   20000000        1113         1248    0.2646   0.0666    0.0879
# 9   6619412   20000000        1081         1271    0.2574   0.0673    0.1041
# 10  6765957   20000000        1046         1294    0.2506   0.0688    0.1197
# 11  6825816   20000000        1005         1319    0.2440   0.0694    0.1271
#
#       margin  fitness  sharpe alpha_id  \
# 0   0.000490     0.73    1.47  RN50wkd
# 1   0.000484     0.71    1.44  3EGgvnX
# 2   0.000477     0.68    1.40  5LGNdq5
# 3   0.000505     0.68    1.35  pnWQdKb
# 4   0.000483     0.67    1.37  mqKed65
# 5   0.000463     0.65    1.35  6RGgLYG
# 6   0.000503     0.64    1.28  LnKvj5v
# 7   0.000484     0.62    1.26  dn9er3j
# 8   0.000503     0.59    1.18  On6KXMJ
# 9   0.000523     0.57    1.12  GnQEXYQ
# 10  0.000549     0.57    1.08  bNx763N
# 11  0.000569     0.55    1.04  0AGnYWq
#
#                                            expression concentrated_weight  \
# 0    trade_when(rank(implied_volatility_call_150)>...                PASS
# 1    trade_when(rank(implied_volatility_call_150)>...                PASS
# 2    trade_when(rank(implied_volatility_call_150)>...                PASS
# 3    trade_when(rank(implied_volatility_call_150)>...                PASS
# 4    trade_when(rank(implied_volatility_call_150)>...                PASS
# 5    if_else(rank(implied_volatility_call_150)>0.1...                PASS
# 6   trade_when(rank(implied_volatility_call_150)>0...                PASS
# 7    if_else(rank(implied_volatility_call_150)>0.1...                PASS
# 8    if_else(rank(implied_volatility_call_150)>0.2...                PASS
# 9    if_else(rank(implied_volatility_call_150)>0.2...                PASS
# 10   if_else(rank(implied_volatility_call_150)>0.3...                PASS
# 11   if_else(rank(implied_volatility_call_150)>0.3...                PASS
#
#    high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0           PASS             FAIL        FAIL       FAIL
# 1           PASS             FAIL        FAIL       FAIL
# 2           PASS             FAIL        FAIL       FAIL
# 3           PASS             FAIL        FAIL       FAIL
# 4           PASS             FAIL        FAIL       FAIL
# 5           PASS             FAIL        FAIL       FAIL
# 6           PASS             FAIL        FAIL       FAIL
# 7           PASS             FAIL        FAIL       FAIL
# 8           PASS             FAIL        FAIL       FAIL
# 9           PASS             FAIL        FAIL       FAIL
# 10          PASS             FAIL        FAIL       FAIL
# 11          PASS             FAIL        FAIL       FAIL
#
#    low_sub_universe_sharpe low_turnover matches_themes
# 0                     PASS         PASS        WARNING
# 1                     PASS         PASS        WARNING
# 2                     FAIL         PASS        WARNING
# 3                     PASS         PASS        WARNING
# 4                     FAIL         PASS        WARNING
# 5                     PASS         PASS        WARNING
# 6                     PASS         PASS        WARNING
# 7                     PASS         PASS        WARNING
# 8                     PASS         PASS        WARNING
# 9                     PASS         PASS        WARNING
# 10                    PASS         PASS        WARNING
# 11                    PASS         PASS        WARNING

# %%
# Selecting the alpha with least turnover
final_alpha = result_st_after[result_st_after['turnover'] == min(result_st_after['turnover'])]['expression'].tolist()[0]
final_alpha
# Out:
# 'trade_when(rank(implied_volatility_call_150)>0.35, zscore(ts_rank(implied_volatility_call_150, 360)) + ts_rank(opt4_30_call_dis_delta40, 30) , -1)'

# %%
# Selecting the best neutralization for the selected alpha
neut_list = ['MARKET' , 'SECTOR' , 'INDUSTRY' , 'SUBINDUSTRY', 'SLOW' , 'FAST' , 'SLOW_AND_FAST']

final_alphas = []
for neut in neut_list:
    alpha_final = [brain.generate_alpha(final_alpha , region= "USA",truncation = 0.08, universe = "TOP3000",pasteurization = 'ON', decay = 4 ,neutralization = neut)]
    result_final = brain.simulate_alpha_list_multi(s, alpha_final)
    results_final = hf.prettify_result(result_final, detailed_tests_view=False)
    final_alphas.append(results_final)
    print(f" For {neut} neutralization, the results are as follows: ")
    display(results_final)
# Out:
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 1/1 [00:40<00:00, 40.15s/it]
#  For MARKET neutralization, the results are as follows:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  3411108   20000000        1316         1145    0.1407   0.0347    0.2288
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000493     0.25     0.5  MbgqK38
#
#                                           expression concentrated_weight  \
# 0  trade_when(rank(implied_volatility_call_150)>0...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 1/1 [00:45<00:00, 45.50s/it]
#  For SECTOR neutralization, the results are as follows:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  3572758   20000000        1291         1170    0.1474   0.0363     0.161
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000493     0.38    0.76  GnQYMOG
#
#                                           expression concentrated_weight  \
# 0  trade_when(rank(implied_volatility_call_150)>0...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 1/1 [00:42<00:00, 42.62s/it]
#  For INDUSTRY neutralization, the results are as follows:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  3619408   20000000        1278         1181    0.1549   0.0368    0.1355
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000475     0.49    1.01  nn6YZP8
#
#                                           expression concentrated_weight  \
# 0  trade_when(rank(implied_volatility_call_150)>0...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    FAIL         PASS        WARNING
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 1/1 [00:34<00:00, 34.87s/it]
#  For SUBINDUSTRY neutralization, the results are as follows:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  4074802   20000000        1230         1154    0.1646   0.0414     0.099
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000503     0.64    1.28  LnKvj5v
#
#                                           expression concentrated_weight  \
# 0  trade_when(rank(implied_volatility_call_150)>0...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|████████████████████████████████████████████| 1/1 [01:58<00:00, 118.17s/it]
#  For SLOW neutralization, the results are as follows:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  5418448   20000000        1542         1560    0.1849   0.0551    0.0262
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000596     1.36    2.49  EqQjA5P
#
#                                           expression concentrated_weight  \
# 0  trade_when(rank(implied_volatility_call_150)>0...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             PASS        PASS       PASS
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|████████████████████████████████████████████| 1/1 [01:47<00:00, 107.15s/it]
#  For FAST neutralization, the results are as follows:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  3401204   20000000        1542         1559    0.1762   0.0346    0.0921
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000392     0.52    1.17  nn6YnV8
#
#                                           expression concentrated_weight  \
# 0  trade_when(rank(implied_volatility_call_150)>0...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             FAIL        FAIL       FAIL
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|████████████████████████████████████████████| 1/1 [02:03<00:00, 123.62s/it]
#  For SLOW_AND_FAST neutralization, the results are as follows:
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  4522348   20000000        1540         1561     0.192    0.046    0.0381
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000479     1.06    2.16  nn6Ynm8
#
#                                           expression concentrated_weight  \
# 0  trade_when(rank(implied_volatility_call_150)>0...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             PASS        PASS       PASS
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING

# %%
final_alpha=final_alphas[4]

# %%
print("Final alpha is:\n",final_alpha['expression'].tolist()[0])
display(final_alpha)
# Out:
# Final alpha is:
#  trade_when(rank(implied_volatility_call_150)>0.35, zscore(ts_rank(implied_volatility_call_150, 360)) + ts_rank(opt4_30_call_dis_delta40, 30) , -1)
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  5418448   20000000        1542         1560    0.1849   0.0551    0.0262
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000596     1.36    2.49  EqQjA5P
#
#                                           expression concentrated_weight  \
# 0  trade_when(rank(implied_volatility_call_150)>0...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             PASS        PASS       PASS
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING

# %% [markdown]
# ### Performing the rank() test :

# %%
test_alpha = f"rank({final_alpha['expression'].tolist()[0]})"
print(test_alpha)
# Out:
# rank(trade_when(rank(implied_volatility_call_150)>0.35, zscore(ts_rank(implied_volatility_call_150, 360)) + ts_rank(opt4_30_call_dis_delta40, 30) , -1))

# %%
test_alpha_final = [brain.generate_alpha(test_alpha , region= "USA",truncation = 0.08, universe = "TOP3000",pasteurization = 'ON', decay = 4 ,neutralization = 'SLOW')]
test_result_final = brain.simulate_alpha_list_multi(s, test_alpha_final)
test_results_final = hf.prettify_result(test_result_final, detailed_tests_view=False)
display(test_results_final)
# Out:
# Warning, list of alphas too short, single concurrent simulations will be used instead of multisimulations
# 100%|█████████████████████████████████████████████| 1/1 [01:31<00:00, 91.90s/it]
#        pnl  book_size  long_count  short_count  turnover  returns  drawdown  \
# 0  4938224   20000000        1490         1611    0.1861   0.0502    0.0229
#
#      margin  fitness  sharpe alpha_id  \
# 0  0.000539     1.28    2.47  v5Ykeow
#
#                                           expression concentrated_weight  \
# 0  rank(trade_when(rank(implied_volatility_call_1...                PASS
#
#   high_turnover is_ladder_sharpe low_fitness low_sharpe  \
# 0          PASS             PASS        PASS       PASS
#
#   low_sub_universe_sharpe low_turnover matches_themes
# 0                    PASS         PASS        WARNING

# %% [markdown]
# ### The metrics remain consistent, indicating that our alpha model is not exhibiting signs of overfitting.

# %% [markdown]
# ## Overfitting Prevention Measures:
# ### 1. In the process of refining our alpha idea, we carefully considered not only the single best-performing expression but rather examined the top three or five performing expressions.
#
# ### 2. The initiation of the alpha idea involved adhering to default settings, prioritizing the enhancement of robustness in our hypothesis over continual adjustment of performance metrics at each step.
#
# ### 3. In the final assessment, a rank() test was conducted on our ultimate alpha expression to assess and mitigate the risk of overfitting.
